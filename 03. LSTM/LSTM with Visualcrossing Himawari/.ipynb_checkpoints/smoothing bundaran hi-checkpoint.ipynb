# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\bundaran_hi.csv"
df_cleaned = pd.read_csv(path)

# Ganti nilai 0 dan "-" jadi NA
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD']
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA

df_cleaned.replace("-", pd.NA, inplace=True)

# Interpolasi kolom
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD']
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

# Drop baris kosong sisa
df_cleaned = df_cleaned.dropna()

# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity   precip  windspeed  \
# 14     52.750000  2022-01-15  26.9  24.5      87.1    3.657       16.6
# 15     52.125000  2022-01-16  27.1  25.3      90.0   11.826       14.6
# 16     51.500000  2022-01-17  27.8  24.9      85.0    5.967       22.1
# 17     51.066667  2022-01-18  26.1  24.7      91.9  163.023       21.7
# 18     39.687500  2022-01-19  27.0  24.2      85.5   53.715       28.5
# ...          ...         ...   ...   ...       ...      ...        ...
# 1088   52.096032  2024-12-24  27.3  23.8      81.8   13.774       23.8
# 1089   56.582540  2024-12-25  27.2  24.4      84.8    6.940       12.8
# 1090   61.069048  2024-12-26  28.5  23.6      75.7    3.904       23.8
# 1091   65.555556  2024-12-27  29.0  23.6      73.4    0.000       18.2
# 1092   58.520833  2024-12-28  29.6  22.6      67.3    0.000       20.8
#
#            AOD
# 14    0.301733
# 15    0.261978
# 16    0.222222
# 17    0.182467
# 18    0.162605
# ...        ...
# 1088  0.143514
# 1089  0.364596
# 1090  0.513231
# 1091  0.589418
# 1092  0.671488
#
# [1079 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(0.2),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model

def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}"
                    print(f"\nTraining model dengan {config_name}")
                    
                    model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate)
                    model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0)
                    
                    metrics = evaluate_model(model, test_gen)
                    print(metrics)
                    
                    results.append({
                        'epochs': epochs,
                        'learning_rate': learning_rate,
                        'optimizer': optimizer,
                        'lstm_units': lstm_units,
                        'R2': metrics['R2'],
                        'RMSE': metrics['RMSE'],
                        'MBE': metrics['MBE'],
                        'NSE': metrics['NSE']
                    })
                    models[config_name] = model
    
    return results, models

# %%
param_grid = {
    'epochs': [10, 30, 50],
    'learning_rate': [0.0001, 0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64]
}

grid_results, models = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_16
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.5511442373551092, 'RMSE': np.float64(0.1285708325741621), 'MBE': np.float64(-0.013216017839480015), 'NSE': np.float64(-171.72197944252883)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'R2': 0.5143875716679027, 'RMSE': np.float64(0.13373157214267156), 'MBE': np.float64(-0.00985654437616533), 'NSE': np.float64(-168.23188893335868)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.537131425905071, 'RMSE': np.float64(0.13056233291609767), 'MBE': np.float64(-0.015951542097097225), 'NSE': np.float64(-172.34826923614122)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.42508978793987306, 'RMSE': np.float64(0.14550873499692873), 'MBE': np.float64(0.01666732238403164), 'NSE': np.float64(-153.71441802806652)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.43754137945465577, 'RMSE': np.float64(0.14392437172658207), 'MBE': np.float64(-0.05186050757440012), 'NSE': np.float64(-175.2830805542922)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.5748275686912174, 'RMSE': np.float64(0.12513292659060257), 'MBE': np.float64(-0.005853269357145936), 'NSE': np.float64(-178.04604385412938)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.4835957127809375, 'RMSE': np.float64(0.13790625763771863), 'MBE': np.float64(-0.019250120074747426), 'NSE': np.float64(-155.54159467373282)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.5392496596052874, 'RMSE': np.float64(0.13026324297621436), 'MBE': np.float64(-0.01638221745957033), 'NSE': np.float64(-163.44873528766652)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# {'R2': 0.503215997022844, 'RMSE': np.float64(0.13526108129446238), 'MBE': np.float64(-0.06546905352894783), 'NSE': np.float64(-191.92503299191904)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'R2': 0.47753785642564994, 'RMSE': np.float64(0.13871277740527727), 'MBE': np.float64(-0.044335415611372275), 'NSE': np.float64(-166.87220461351438)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'R2': 0.5042337514095644, 'RMSE': np.float64(0.13512245652276433), 'MBE': np.float64(-0.004249122435333336), 'NSE': np.float64(-156.996697460167)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# {'R2': 0.682225402591394, 'RMSE': np.float64(0.10818041476434413), 'MBE': np.float64(-0.05028600617917459), 'NSE': np.float64(-244.4682102447211)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# {'R2': 0.6184004337764173, 'RMSE': np.float64(0.1185476610588473), 'MBE': np.float64(-0.007181247720823572), 'NSE': np.float64(-163.79290855220077)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units        R2      RMSE       MBE  \
# 0       10         0.0001      adam          16  0.551144  0.128571 -0.013216
# 1       10         0.0001      adam          32  0.514388  0.133732 -0.009857
# 2       10         0.0001      adam          64  0.537131  0.130562 -0.015952
# 3       10         0.0001   rmsprop          16  0.425090  0.145509  0.016667
# 4       10         0.0001   rmsprop          32  0.437541  0.143924 -0.051861
# 5       10         0.0001   rmsprop          64  0.574828  0.125133 -0.005853
# 6       10         0.0010      adam          16  0.483596  0.137906 -0.019250
# 7       10         0.0010      adam          32  0.539250  0.130263 -0.016382
# 8       10         0.0010      adam          64  0.503216  0.135261 -0.065469
# 9       10         0.0010   rmsprop          16  0.477538  0.138713 -0.044335
# 10      10         0.0010   rmsprop          32  0.504234  0.135122 -0.004249
# 11      10         0.0010   rmsprop          64  0.468762  0.139873 -0.081414
# 12      10         0.0100      adam          16  0.447823  0.142603 -0.055532
# 13      10         0.0100      adam          32  0.592159  0.122556 -0.045727
# 14      10         0.0100      adam          64  0.593062  0.122420 -0.046843
# 15      10         0.0100   rmsprop          16  0.661632  0.111631 -0.018959
# 16      10         0.0100   rmsprop          32  0.616885  0.118783 -0.047914
# 17      10         0.0100   rmsprop          64  0.322567  0.157951 -0.122122
# 18      30         0.0001      adam          16  0.437205  0.143967  0.028471
# 19      30         0.0001      adam          32  0.566718  0.126321  0.003365
# 20      30         0.0001      adam          64  0.578667  0.124567 -0.027869
# 21      30         0.0001   rmsprop          16  0.421691  0.145938 -0.046495
# 22      30         0.0001   rmsprop          32  0.535469  0.130797 -0.015533
# 23      30         0.0001   rmsprop          64  0.553352  0.128254 -0.037243
# 24      30         0.0010      adam          16  0.612519  0.119458 -0.014179
# 25      30         0.0010      adam          32  0.683570  0.107951 -0.031028
# 26      30         0.0010      adam          64  0.605297  0.120566 -0.067633
# 27      30         0.0010   rmsprop          16  0.532168  0.131260 -0.067259
# 28      30         0.0010   rmsprop          32  0.574438  0.125190 -0.031510
# 29      30         0.0010   rmsprop          64  0.590802  0.122760 -0.072251
# 30      30         0.0100      adam          16  0.641847  0.114848 -0.003366
# 31      30         0.0100      adam          32  0.570391  0.125784 -0.052889
# 32      30         0.0100      adam          64  0.620735  0.118185 -0.040300
# 33      30         0.0100   rmsprop          16  0.676902  0.109083 -0.024814
# 34      30         0.0100   rmsprop          32  0.610153  0.119822 -0.050055
# 35      30         0.0100   rmsprop          64  0.662940  0.111415 -0.029769
# 36      50         0.0001      adam          16  0.461339  0.140847 -0.036662
# 37      50         0.0001      adam          32  0.600440  0.121305 -0.002208
# 38      50         0.0001      adam          64  0.591760  0.122616 -0.018602
# 39      50         0.0001   rmsprop          16  0.498775  0.135864 -0.030719
# 40      50         0.0001   rmsprop          32  0.550486  0.128665  0.005812
# 41      50         0.0001   rmsprop          64  0.571478  0.125625 -0.037104
# 42      50         0.0010      adam          16  0.592500  0.122505 -0.041963
# 43      50         0.0010      adam          32  0.684167  0.107849 -0.038558
# 44      50         0.0010      adam          64  0.716459  0.102187 -0.019784
# 45      50         0.0010   rmsprop          16  0.584076  0.123764  0.020999
# 46      50         0.0010   rmsprop          32  0.594745  0.122167 -0.057750
# 47      50         0.0010   rmsprop          64  0.721984  0.101187 -0.038348
# 48      50         0.0100      adam          16  0.555393  0.127961  0.026655
# 49      50         0.0100      adam          32  0.626858  0.117227  0.017150
# 50      50         0.0100      adam          64  0.653780  0.112918  0.016091
# 51      50         0.0100   rmsprop          16  0.649717  0.113579 -0.046027
# 52      50         0.0100   rmsprop          32  0.682225  0.108180 -0.050286
# 53      50         0.0100   rmsprop          64  0.618400  0.118548 -0.007181
#
#            NSE
# 0  -171.721979
# 1  -168.231889
# 2  -172.348269
# 3  -153.714418
# 4  -175.283081
# 5  -178.046044
# 6  -155.541595
# 7  -163.448735
# 8  -191.925033
# 9  -166.872205
# 10 -156.996697
# 11 -214.309107
# 12 -169.487692
# 13 -182.837315
# 14 -191.514645
# 15 -184.637925
# 16 -187.669152
# 17 -261.574514
# 18 -158.327354
# 19 -173.096354
# 20 -187.726457
# 21 -163.636553
# 22 -168.035190
# 23 -187.320702
# 24 -173.469754
# 25 -198.086499
# 26 -221.643260
# 27 -199.637403
# 28 -173.651243
# 29 -227.572849
# 30 -172.064951
# 31 -195.015871
# 32 -180.852969
# 33 -186.270431
# 34 -189.942603
# 35 -182.946555
# 36 -167.727687
# 37 -174.159214
# 38 -181.757221
# 39 -168.300910
# 40 -167.742808
# 41 -183.887560
# 42 -176.578227
# 43 -201.513830
# 44 -193.863704
# 45 -163.292434
# 46 -196.434719
# 47 -209.673235
# 48 -161.362825
# 49 -171.438867
# 50 -173.674625
# 51 -191.786656
# 52 -244.468210
# 53 -163.792909

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}"
best_model = models[best_model_name]

best_model.save("bundaran_hi.keras")

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065
# Test Loss: 0.010238776914775372

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.7220
# Test RMSE: 0.1012
# Test MBE: -0.0383
# Test NSE: -209.6732

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
#  27/264 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("bundaran_hi results.csv", index=False)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.initializers import glorot_uniform

model = load_model("bundaran_hi.keras")


# Fungsi untuk me-reset bobot model
def reset_weights(model):
    for layer in model.layers:
        # Reset weights untuk layer yang memiliki weights (Dense, Conv2D, LSTM, dll.)
        if hasattr(layer, 'weights'):
            for weight in layer.weights:
                # Dapatkan initializer yang sesuai
                if 'kernel' in weight.name:
                    initializer = layer.kernel_initializer
                elif 'bias' in weight.name:
                    initializer = layer.bias_initializer
                elif 'recurrent_kernel' in weight.name:
                    initializer = layer.recurrent_initializer
                else:
                    continue  # Lewati jika tidak dikenali
                
                # Reset nilai weights
                new_weights = initializer(weight.shape)
                weight.assign(new_weights)
# Reset bobot model
reset_weights(model)


class R2History(Callback):
    def __init__(self, val_gen):
        self.val_gen = val_gen
        self.r2_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_pred = self.model.predict(self.val_gen)

        val_true_list = []
        for i in range(len(test_gen)):  
            _, y =  val_gen[i]  # Ambil hanya nilai target dari generator
            val_true_list.append(y)
        
        val_true = np.hstack(val_true_list)  # Gabungkan list ke array numpy
                        
        r2 = r2_score(val_true, val_pred)
        self.r2_scores.append(r2)

r2_callback = R2History(val_gen)

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=100, callbacks=[r2_callback])
# Out:
# Epoch 1/100
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step p - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0872 - val_loss: 0.0168
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0230 - val_loss: 0.0141
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0177 - val_loss: 0.0166
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0189 - val_loss: 0.0163
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0161 - val_loss: 0.0126
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0189 - val_loss: 0.0124
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0126 - val_loss: 0.0119
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0152 - val_loss: 0.0140
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0135 - val_loss: 0.0148
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0157 - val_loss: 0.0103
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0134 - val_loss: 0.0124
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0131 - val_loss: 0.0105
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0145 - val_loss: 0.0095
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0140 - val_loss: 0.0093
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0123 - val_loss: 0.0097
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0121 - val_loss: 0.0089
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0124 - val_loss: 0.0088
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0107 - val_loss: 0.0088
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0117 - val_loss: 0.0084
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0115 - val_loss: 0.0093
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0108 - val_loss: 0.0084
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0109 - val_loss: 0.0086
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0097 - val_loss: 0.0086
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0121 - val_loss: 0.0082
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0126 - val_loss: 0.0084
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0097 - val_loss: 0.0082
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0111 - val_loss: 0.0096
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0116 - val_loss: 0.0078
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0098 - val_loss: 0.0083
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0108 - val_loss: 0.0084
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0101 - val_loss: 0.0078
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0110 - val_loss: 0.0084
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0093 - val_loss: 0.0081
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0102 - val_loss: 0.0097
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0097 - val_loss: 0.0082
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0108 - val_loss: 0.0078
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0098 - val_loss: 0.0093
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0107 - val_loss: 0.0087
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0106 - val_loss: 0.0079
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0101 - val_loss: 0.0086
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0129 - val_loss: 0.0081
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0104 - val_loss: 0.0173
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0102 - val_loss: 0.0084
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0113 - val_loss: 0.0083
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0099 - val_loss: 0.0116
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0122 - val_loss: 0.0080
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0096 - val_loss: 0.0086
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0089 - val_loss: 0.0084
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0115 - val_loss: 0.0090
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0120 - val_loss: 0.0082
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0096 - val_loss: 0.0099
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0099 - val_loss: 0.0081
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0096 - val_loss: 0.0081
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0090 - val_loss: 0.0088
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0090 - val_loss: 0.0083
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0099 - val_loss: 0.0085
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0095 - val_loss: 0.0083
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0081 - val_loss: 0.0081
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0096 - val_loss: 0.0083
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0090 - val_loss: 0.0084
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0105 - val_loss: 0.0083
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0104 - val_loss: 0.0088
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0093 - val_loss: 0.0088
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0108 - val_loss: 0.0085
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0094 - val_loss: 0.0089
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0089 - val_loss: 0.0090
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0116 - val_loss: 0.0106
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0104 - val_loss: 0.0088
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0092 - val_loss: 0.0088
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0093 - val_loss: 0.0093
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0092 - val_loss: 0.0088
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0079 - val_loss: 0.0089
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0083 - val_loss: 0.0103
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0077 - val_loss: 0.0098
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0081 - val_loss: 0.0107
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0096 - val_loss: 0.0089
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0093 - val_loss: 0.0087
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0097 - val_loss: 0.0098
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0099 - val_loss: 0.0094
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0088 - val_loss: 0.0094
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0085 - val_loss: 0.0108
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0080 - val_loss: 0.0121

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
r2_scores = r2_callback.r2_scores

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i] 
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  
test_pred = model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 12/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.7620
# Test RMSE: 0.0933
# Test MBE: -0.0094
# Test NSE: -208.8289

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
