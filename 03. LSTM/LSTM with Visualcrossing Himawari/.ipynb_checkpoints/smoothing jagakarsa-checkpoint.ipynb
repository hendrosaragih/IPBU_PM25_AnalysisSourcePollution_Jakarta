# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\jagakarsa.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 14     68.833333  2022-01-15  26.7  24.3      87.2   5.342       16.6
# 15     80.916667  2022-01-16  26.9  25.2      90.3   6.368       11.6
# 16     93.000000  2022-01-17  27.7  24.7      84.6   9.578       18.4
# 17     62.133333  2022-01-18  25.9  24.6      92.5  92.373       18.4
# 18     57.500000  2022-01-19  26.9  24.0      85.1  48.866       27.7
# ...          ...         ...   ...   ...       ...     ...        ...
# 1088   63.157937  2024-12-24  27.0  23.7      82.9  16.934       24.8
# 1089   69.734921  2024-12-25  26.9  24.1      85.1   6.804       12.4
# 1090   76.311905  2024-12-26  28.2  23.3      75.9   2.249       24.8
# 1091   82.888889  2024-12-27  28.8  23.2      73.2   0.000       16.7
# 1092   74.833333  2024-12-28  29.4  22.2      66.7   0.044       21.2
#
#            AOD
# 14    0.112123
# 15    0.112969
# 16    0.113815
# 17    0.114662
# 18    0.118158
# ...        ...
# 1088  0.387357
# 1089  0.305876
# 1090  0.231514
# 1091  0.164271
# 1092  0.104148
#
# [1079 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(0.2),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model

def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}"
                    print(f"\nTraining model dengan {config_name}")
                    
                    model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate)
                    model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0)
                    
                    metrics = evaluate_model(model, test_gen)
                    print(metrics)
                    
                    results.append({
                        'epochs': epochs,
                        'learning_rate': learning_rate,
                        'optimizer': optimizer,
                        'lstm_units': lstm_units,
                        'R2': metrics['R2'],
                        'RMSE': metrics['RMSE'],
                        'MBE': metrics['MBE'],
                        'NSE': metrics['NSE']
                    })
                    models[config_name] = model
    
    return results, models

# %%
param_grid = {
    'epochs': [10, 30, 50],
    'learning_rate': [0.0001, 0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64]
}

grid_results, models = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_16
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.09811513081417134, 'RMSE': np.float64(0.11619905921481977), 'MBE': np.float64(-0.0006656501334930984), 'NSE': np.float64(-135.84939237759397)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.13624366643448338, 'RMSE': np.float64(0.11371629039744983), 'MBE': np.float64(0.03842316665160759), 'NSE': np.float64(-156.61524273471795)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.14345031448533796, 'RMSE': np.float64(0.11324090758583619), 'MBE': np.float64(0.060908219345743225), 'NSE': np.float64(-194.75228779921875)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.059697270442655936, 'RMSE': np.float64(0.1186481333057936), 'MBE': np.float64(0.013330039109140324), 'NSE': np.float64(-138.07875192172915)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.200136830739867, 'RMSE': np.float64(0.10942962507022268), 'MBE': np.float64(0.02172540692545331), 'NSE': np.float64(-148.987368243075)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# {'R2': 0.2741942411671051, 'RMSE': np.float64(0.1042406873294727), 'MBE': np.float64(0.0351513249156254), 'NSE': np.float64(-168.08472608064196)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.21610751782189586, 'RMSE': np.float64(0.10833163832887818), 'MBE': np.float64(0.02180506364027702), 'NSE': np.float64(-143.8634512186038)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.29688613321538737, 'RMSE': np.float64(0.10259823579325862), 'MBE': np.float64(-0.046849235809287786), 'NSE': np.float64(-188.18437566988774)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.48195739191236964, 'RMSE': np.float64(0.08806631047530415), 'MBE': np.float64(0.006756828652662264), 'NSE': np.float64(-177.5103450018144)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.27563584483302295, 'RMSE': np.float64(0.1041371138539107), 'MBE': np.float64(0.02285084781656261), 'NSE': np.float64(-148.08102350458026)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.19454332383596085, 'RMSE': np.float64(0.10981158351279671), 'MBE': np.float64(-0.06306808489177908), 'NSE': np.float64(-210.37115277654775)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# {'R2': 0.06725582824074505, 'RMSE': np.float64(0.11817029874315227), 'MBE': np.float64(-0.07794982275561864), 'NSE': np.float64(-225.63701048054457)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': -0.556853433781074, 'RMSE': np.float64(0.15266902283544895), 'MBE': np.float64(0.11428637988825979), 'NSE': np.float64(-271.4091438922512)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.21564164480157377, 'RMSE': np.float64(0.10836382468888749), 'MBE': np.float64(-0.03376301403071707), 'NSE': np.float64(-153.8036108230581)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.4478362476251061, 'RMSE': np.float64(0.09092033099442295), 'MBE': np.float64(0.014198625571075797), 'NSE': np.float64(-157.81402736860701)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.3563788371004626, 'RMSE': np.float64(0.09816173350435747), 'MBE': np.float64(-0.04624971405489485), 'NSE': np.float64(-178.79727167309406)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5265552314174844, 'RMSE': np.float64(0.0841902351397971), 'MBE': np.float64(-0.023914715386765085), 'NSE': np.float64(-181.32990828347218)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.3713537502960951, 'RMSE': np.float64(0.09701306504358097), 'MBE': np.float64(-0.05388133975702689), 'NSE': np.float64(-199.8630171884)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.2489751815061979, 'RMSE': np.float64(0.10603621229022389), 'MBE': np.float64(0.008426089645594935), 'NSE': np.float64(-143.24765488946122)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.13918279498277963, 'RMSE': np.float64(0.11352265268501625), 'MBE': np.float64(0.06243160931326307), 'NSE': np.float64(-201.5859919578712)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.41518811901033037, 'RMSE': np.float64(0.0935696823212646), 'MBE': np.float64(-0.026083873640861843), 'NSE': np.float64(-194.09007698830587)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.30218763980827745, 'RMSE': np.float64(0.10221070651996435), 'MBE': np.float64(0.010803673110174732), 'NSE': np.float64(-148.89017895329005)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.3315405629063116, 'RMSE': np.float64(0.10003790563487676), 'MBE': np.float64(-0.016040028615400725), 'NSE': np.float64(-159.04968328380687)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.39167276607021384, 'RMSE': np.float64(0.09543236601791058), 'MBE': np.float64(0.01581342126300722), 'NSE': np.float64(-165.16436188332773)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.47567837302637506, 'RMSE': np.float64(0.08859841392188257), 'MBE': np.float64(-0.013141057523945237), 'NSE': np.float64(-174.11460290544917)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.5844988293490974, 'RMSE': np.float64(0.07887024452673344), 'MBE': np.float64(0.004944309897660456), 'NSE': np.float64(-196.686386841661)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.5193772104617975, 'RMSE': np.float64(0.08482604944400574), 'MBE': np.float64(-0.0360209551824499), 'NSE': np.float64(-217.0972935889491)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.14622856420200758, 'RMSE': np.float64(0.1130571079459781), 'MBE': np.float64(0.05558264019178556), 'NSE': np.float64(-175.28188259504967)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# {'R2': 0.4761658227471447, 'RMSE': np.float64(0.08855722039473647), 'MBE': np.float64(-0.001213613202939146), 'NSE': np.float64(-169.17846134533397)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# {'R2': 0.48565997929804816, 'RMSE': np.float64(0.08775102952207957), 'MBE': np.float64(0.018941761703017177), 'NSE': np.float64(-168.35424436039284)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.3980621461984797, 'RMSE': np.float64(0.09492987066395771), 'MBE': np.float64(-0.008148170591017067), 'NSE': np.float64(-150.52702504610937)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5160528991457146, 'RMSE': np.float64(0.08511890100671882), 'MBE': np.float64(-0.02626167540825379), 'NSE': np.float64(-188.73321408204464)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.421489043081995, 'RMSE': np.float64(0.0930642444547088), 'MBE': np.float64(-0.04706289066013369), 'NSE': np.float64(-195.68032931783517)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.24703835714308164, 'RMSE': np.float64(0.10617285310079383), 'MBE': np.float64(0.0383658850311407), 'NSE': np.float64(-157.52260783798647)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5264133210944011, 'RMSE': np.float64(0.08420285178392643), 'MBE': np.float64(-0.023402943679372634), 'NSE': np.float64(-193.3123763915303)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.5287592263793073, 'RMSE': np.float64(0.0839940440307983), 'MBE': np.float64(0.01909123636297962), 'NSE': np.float64(-175.854703550734)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.29336034762347984, 'RMSE': np.float64(0.10285515508030414), 'MBE': np.float64(0.03792660880738866), 'NSE': np.float64(-173.76518421984957)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.38159052442796515, 'RMSE': np.float64(0.09621995050242545), 'MBE': np.float64(-0.00999161837411714), 'NSE': np.float64(-160.75309942714588)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# {'R2': 0.43331957310268, 'RMSE': np.float64(0.09210774875146614), 'MBE': np.float64(-0.002669988867678614), 'NSE': np.float64(-172.91694433989704)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.2743883613494935, 'RMSE': np.float64(0.10422674656489982), 'MBE': np.float64(0.036305868886573237), 'NSE': np.float64(-173.48058623687388)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.41321950290644116, 'RMSE': np.float64(0.09372703892788406), 'MBE': np.float64(-0.011256032609844249), 'NSE': np.float64(-167.80572301392425)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.3827299077735107, 'RMSE': np.float64(0.09613126981642015), 'MBE': np.float64(0.021372904389035483), 'NSE': np.float64(-171.143668824581)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.5559916104169642, 'RMSE': np.float64(0.08153097755801912), 'MBE': np.float64(0.002819879369332856), 'NSE': np.float64(-182.61083700596132)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# {'R2': 0.5426130672663898, 'RMSE': np.float64(0.08275017824006968), 'MBE': np.float64(-0.023518684112040725), 'NSE': np.float64(-187.19198226731896)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# {'R2': 0.5665737892028018, 'RMSE': np.float64(0.0805535430293988), 'MBE': np.float64(-0.015012857991094777), 'NSE': np.float64(-183.99462432732702)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.45366469547880417, 'RMSE': np.float64(0.09043919631315767), 'MBE': np.float64(0.0093457552864544), 'NSE': np.float64(-166.58659258303715)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# {'R2': 0.5925632244864139, 'RMSE': np.float64(0.07810110428948046), 'MBE': np.float64(-0.011866790729398915), 'NSE': np.float64(-203.93152906462058)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.5938655074180037, 'RMSE': np.float64(0.07797618780602426), 'MBE': np.float64(0.01863546121770513), 'NSE': np.float64(-192.7003726208717)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.6161353733601388, 'RMSE': np.float64(0.0758081866209361), 'MBE': np.float64(-0.00598936063735596), 'NSE': np.float64(-195.11871694216316)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# {'R2': 0.5452562589476533, 'RMSE': np.float64(0.08251072944943727), 'MBE': np.float64(-0.03414497126989654), 'NSE': np.float64(-215.37801434041398)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# {'R2': 0.5735984418642734, 'RMSE': np.float64(0.0798981002117846), 'MBE': np.float64(-0.014105363040444433), 'NSE': np.float64(-202.7940983254253)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.4473436949561874, 'RMSE': np.float64(0.09096087428332127), 'MBE': np.float64(0.02297107839166864), 'NSE': np.float64(-166.40772723398516)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.5711995283331055, 'RMSE': np.float64(0.08012253631693364), 'MBE': np.float64(-0.023528032477838644), 'NSE': np.float64(-198.82256405177753)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.4811904087768918, 'RMSE': np.float64(0.08813147923889263), 'MBE': np.float64(0.022709654643737694), 'NSE': np.float64(-166.9838049347253)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units        R2      RMSE       MBE  \
# 0       10         0.0001      adam          16  0.098115  0.116199 -0.000666
# 1       10         0.0001      adam          32  0.136244  0.113716  0.038423
# 2       10         0.0001      adam          64  0.143450  0.113241  0.060908
# 3       10         0.0001   rmsprop          16  0.059697  0.118648  0.013330
# 4       10         0.0001   rmsprop          32  0.200137  0.109430  0.021725
# 5       10         0.0001   rmsprop          64  0.274194  0.104241  0.035151
# 6       10         0.0010      adam          16  0.216108  0.108332  0.021805
# 7       10         0.0010      adam          32  0.296886  0.102598 -0.046849
# 8       10         0.0010      adam          64  0.481957  0.088066  0.006757
# 9       10         0.0010   rmsprop          16  0.275636  0.104137  0.022851
# 10      10         0.0010   rmsprop          32  0.194543  0.109812 -0.063068
# 11      10         0.0010   rmsprop          64  0.067256  0.118170 -0.077950
# 12      10         0.0100      adam          16 -0.556853  0.152669  0.114286
# 13      10         0.0100      adam          32  0.215642  0.108364 -0.033763
# 14      10         0.0100      adam          64  0.447836  0.090920  0.014199
# 15      10         0.0100   rmsprop          16  0.356379  0.098162 -0.046250
# 16      10         0.0100   rmsprop          32  0.526555  0.084190 -0.023915
# 17      10         0.0100   rmsprop          64  0.371354  0.097013 -0.053881
# 18      30         0.0001      adam          16  0.248975  0.106036  0.008426
# 19      30         0.0001      adam          32  0.139183  0.113523  0.062432
# 20      30         0.0001      adam          64  0.415188  0.093570 -0.026084
# 21      30         0.0001   rmsprop          16  0.302188  0.102211  0.010804
# 22      30         0.0001   rmsprop          32  0.331541  0.100038 -0.016040
# 23      30         0.0001   rmsprop          64  0.391673  0.095432  0.015813
# 24      30         0.0010      adam          16  0.475678  0.088598 -0.013141
# 25      30         0.0010      adam          32  0.584499  0.078870  0.004944
# 26      30         0.0010      adam          64  0.519377  0.084826 -0.036021
# 27      30         0.0010   rmsprop          16  0.146229  0.113057  0.055583
# 28      30         0.0010   rmsprop          32  0.476166  0.088557 -0.001214
# 29      30         0.0010   rmsprop          64  0.485660  0.087751  0.018942
# 30      30         0.0100      adam          16  0.398062  0.094930 -0.008148
# 31      30         0.0100      adam          32  0.516053  0.085119 -0.026262
# 32      30         0.0100      adam          64  0.421489  0.093064 -0.047063
# 33      30         0.0100   rmsprop          16  0.247038  0.106173  0.038366
# 34      30         0.0100   rmsprop          32  0.526413  0.084203 -0.023403
# 35      30         0.0100   rmsprop          64  0.528759  0.083994  0.019091
# 36      50         0.0001      adam          16  0.293360  0.102855  0.037927
# 37      50         0.0001      adam          32  0.381591  0.096220 -0.009992
# 38      50         0.0001      adam          64  0.433320  0.092108 -0.002670
# 39      50         0.0001   rmsprop          16  0.274388  0.104227  0.036306
# 40      50         0.0001   rmsprop          32  0.413220  0.093727 -0.011256
# 41      50         0.0001   rmsprop          64  0.382730  0.096131  0.021373
# 42      50         0.0010      adam          16  0.555992  0.081531  0.002820
# 43      50         0.0010      adam          32  0.542613  0.082750 -0.023519
# 44      50         0.0010      adam          64  0.566574  0.080554 -0.015013
# 45      50         0.0010   rmsprop          16  0.453665  0.090439  0.009346
# 46      50         0.0010   rmsprop          32  0.592563  0.078101 -0.011867
# 47      50         0.0010   rmsprop          64  0.593866  0.077976  0.018635
# 48      50         0.0100      adam          16  0.616135  0.075808 -0.005989
# 49      50         0.0100      adam          32  0.545256  0.082511 -0.034145
# 50      50         0.0100      adam          64  0.573598  0.079898 -0.014105
# 51      50         0.0100   rmsprop          16  0.447344  0.090961  0.022971
# 52      50         0.0100   rmsprop          32  0.571200  0.080123 -0.023528
# 53      50         0.0100   rmsprop          64  0.481190  0.088131  0.022710
#
#            NSE
# 0  -135.849392
# 1  -156.615243
# 2  -194.752288
# 3  -138.078752
# 4  -148.987368
# 5  -168.084726
# 6  -143.863451
# 7  -188.184376
# 8  -177.510345
# 9  -148.081024
# 10 -210.371153
# 11 -225.637010
# 12 -271.409144
# 13 -153.803611
# 14 -157.814027
# 15 -178.797272
# 16 -181.329908
# 17 -199.863017
# 18 -143.247655
# 19 -201.585992
# 20 -194.090077
# 21 -148.890179
# 22 -159.049683
# 23 -165.164362
# 24 -174.114603
# 25 -196.686387
# 26 -217.097294
# 27 -175.281883
# 28 -169.178461
# 29 -168.354244
# 30 -150.527025
# 31 -188.733214
# 32 -195.680329
# 33 -157.522608
# 34 -193.312376
# 35 -175.854704
# 36 -173.765184
# 37 -160.753099
# 38 -172.916944
# 39 -173.480586
# 40 -167.805723
# 41 -171.143669
# 42 -182.610837
# 43 -187.191982
# 44 -183.994624
# 45 -166.586593
# 46 -203.931529
# 47 -192.700373
# 48 -195.118717
# 49 -215.378014
# 50 -202.794098
# 51 -166.407727
# 52 -198.822564
# 53 -166.983805

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}"
best_model = models[best_model_name]

best_model.save("jagakarsa.keras")

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045
# Test Loss: 0.005746880546212196

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.6161
# Test RMSE: 0.0758
# Test MBE: -0.0060
# Test NSE: -195.1187

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
#  14/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("jagakarsa results.csv", index=False)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.initializers import glorot_uniform

model = load_model("jagakarsa.keras")


# Fungsi untuk me-reset bobot model
def reset_weights(model):
    for layer in model.layers:
        # Reset weights untuk layer yang memiliki weights (Dense, Conv2D, LSTM, dll.)
        if hasattr(layer, 'weights'):
            for weight in layer.weights:
                # Dapatkan initializer yang sesuai
                if 'kernel' in weight.name:
                    initializer = layer.kernel_initializer
                elif 'bias' in weight.name:
                    initializer = layer.bias_initializer
                elif 'recurrent_kernel' in weight.name:
                    initializer = layer.recurrent_initializer
                else:
                    continue  # Lewati jika tidak dikenali
                
                # Reset nilai weights
                new_weights = initializer(weight.shape)
                weight.assign(new_weights)
# Reset bobot model
reset_weights(model)


class R2History(Callback):
    def __init__(self, val_gen):
        self.val_gen = val_gen
        self.r2_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_pred = self.model.predict(self.val_gen)

        val_true_list = []
        for i in range(len(test_gen)):  
            _, y =  val_gen[i]  # Ambil hanya nilai target dari generator
            val_true_list.append(y)
        
        val_true = np.hstack(val_true_list)  # Gabungkan list ke array numpy
                        
        r2 = r2_score(val_true, val_pred)
        self.r2_scores.append(r2)

r2_callback = R2History(val_gen)

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=100, callbacks=[r2_callback])
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step   - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - loss: 0.0429 - val_loss: 0.0143
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0247 - val_loss: 0.0143
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0201 - val_loss: 0.0140
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0190 - val_loss: 0.0153
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0176 - val_loss: 0.0144
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0209 - val_loss: 0.0153
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0191 - val_loss: 0.0122
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0189 - val_loss: 0.0117
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0163 - val_loss: 0.0101
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0164 - val_loss: 0.0101
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0176 - val_loss: 0.0104
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0138 - val_loss: 0.0111
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0140 - val_loss: 0.0131
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0120 - val_loss: 0.0101
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0140 - val_loss: 0.0097
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0135 - val_loss: 0.0121
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0111 - val_loss: 0.0127
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0144 - val_loss: 0.0103
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0141 - val_loss: 0.0099
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0126 - val_loss: 0.0112
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0134 - val_loss: 0.0138
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0101
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0148 - val_loss: 0.0105
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0111 - val_loss: 0.0099
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0122 - val_loss: 0.0100
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0122 - val_loss: 0.0129
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0127 - val_loss: 0.0103
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0137 - val_loss: 0.0103
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0127 - val_loss: 0.0125
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0138 - val_loss: 0.0107
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0122 - val_loss: 0.0103
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0129 - val_loss: 0.0123
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0115 - val_loss: 0.0104
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0129 - val_loss: 0.0130
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0134 - val_loss: 0.0109
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0125 - val_loss: 0.0131
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0116 - val_loss: 0.0102
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0141 - val_loss: 0.0124
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0128 - val_loss: 0.0110
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0099
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0108
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0150 - val_loss: 0.0106
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0118 - val_loss: 0.0107
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0134 - val_loss: 0.0113
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0136 - val_loss: 0.0101
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0121 - val_loss: 0.0098
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0117 - val_loss: 0.0123
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0125 - val_loss: 0.0152
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0125 - val_loss: 0.0107
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0132 - val_loss: 0.0097
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0128 - val_loss: 0.0105
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0138 - val_loss: 0.0100
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0120 - val_loss: 0.0125
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0129 - val_loss: 0.0098
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0102 - val_loss: 0.0176
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0141 - val_loss: 0.0111
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0098 - val_loss: 0.0102
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0108 - val_loss: 0.0100
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0187 - val_loss: 0.0101
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0134 - val_loss: 0.0112
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0134 - val_loss: 0.0118
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0125 - val_loss: 0.0099
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0122 - val_loss: 0.0102
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0138 - val_loss: 0.0096
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0123 - val_loss: 0.0095
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0140 - val_loss: 0.0099
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0108
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0116 - val_loss: 0.0113
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0136 - val_loss: 0.0114
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0108 - val_loss: 0.0098
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0118 - val_loss: 0.0098
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0116 - val_loss: 0.0120
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0140 - val_loss: 0.0097
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0138 - val_loss: 0.0129
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0109 - val_loss: 0.0110
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0130 - val_loss: 0.0107
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0128 - val_loss: 0.0122
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0139 - val_loss: 0.0105
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0121 - val_loss: 0.0131
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0125 - val_loss: 0.0109
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0123 - val_loss: 0.0117
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0132 - val_loss: 0.0115
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0101 - val_loss: 0.0105
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0121
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0149 - val_loss: 0.0102
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0149 - val_loss: 0.0101
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0111
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0132 - val_loss: 0.0093
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0130 - val_loss: 0.0098
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0137 - val_loss: 0.0112
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0138 - val_loss: 0.0109
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0103 - val_loss: 0.0102
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0127 - val_loss: 0.0117
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0101 - val_loss: 0.0112
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0141 - val_loss: 0.0101
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0136 - val_loss: 0.0092

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
r2_scores = r2_callback.r2_scores

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i] 
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  
test_pred = model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.5593
# Test RMSE: 0.0826
# Test MBE: -0.0168
# Test NSE: -199.2684
