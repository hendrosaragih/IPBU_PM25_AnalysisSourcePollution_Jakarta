# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\us_embassy_2.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 9      62.700470  2022-01-10  27.9  24.6      83.0  11.234       19.8
# 10     57.229170  2022-01-11  26.5  24.4      89.2  57.783       16.3
# 11     56.911388  2022-01-12  26.4  24.2      88.4  17.907       21.6
# 12     54.847979  2022-01-13  27.0  24.3      85.5   3.269       24.1
# 13     57.993500  2022-01-14  26.8  24.4      87.1  14.312       19.3
# ...          ...         ...   ...   ...       ...     ...        ...
# 1088   57.585364  2024-12-24  27.2  23.8      82.4  16.514       23.5
# 1089   38.936576  2024-12-25  27.1  24.3      84.9   6.508       12.9
# 1090   56.567064  2024-12-26  28.4  23.6      76.3   3.162       23.5
# 1091   54.071933  2024-12-27  28.9  23.5      73.6   0.000       17.2
# 1092   65.191038  2024-12-28  29.5  22.5      67.4   0.007       20.7
#
#            AOD
# 9     0.147036
# 10    0.161091
# 11    0.189655
# 12    0.218218
# 13    0.246782
# ...        ...
# 1088  0.633800
# 1089  0.583914
# 1090  0.518143
# 1091  0.436486
# 1092  0.338943
#
# [1084 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(0.2),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model

def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}"
                    print(f"\nTraining model dengan {config_name}")
                    
                    model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate)
                    model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0)
                    
                    metrics = evaluate_model(model, test_gen)
                    print(metrics)
                    
                    results.append({
                        'epochs': epochs,
                        'learning_rate': learning_rate,
                        'optimizer': optimizer,
                        'lstm_units': lstm_units,
                        'R2': metrics['R2'],
                        'RMSE': metrics['RMSE'],
                        'MBE': metrics['MBE'],
                        'NSE': metrics['NSE']
                    })
                    models[config_name] = model
    
    return results, models

# %%
param_grid = {
    'epochs': [10, 30, 50],
    'learning_rate': [0.0001, 0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64]
}

grid_results, models = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_16
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'R2': 0.1491481765905749, 'RMSE': np.float64(0.180860053911537), 'MBE': np.float64(0.060445402266578255), 'NSE': np.float64(-157.69331165926496)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# {'R2': 0.3518984815661591, 'RMSE': np.float64(0.15784731848726807), 'MBE': np.float64(-0.02435335433106878), 'NSE': np.float64(-161.63625968047938)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# {'R2': 0.33919867517858393, 'RMSE': np.float64(0.15938635596797635), 'MBE': np.float64(-0.02585086253843265), 'NSE': np.float64(-157.84061865945966)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# {'R2': 0.3439259894259946, 'RMSE': np.float64(0.15881521471247137), 'MBE': np.float64(-0.00755631461763624), 'NSE': np.float64(-157.91775688071803)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# {'R2': 0.2892016479417424, 'RMSE': np.float64(0.16530610580920366), 'MBE': np.float64(0.009848429811738568), 'NSE': np.float64(-151.32330002373314)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.3094455147269307, 'RMSE': np.float64(0.16293510477667456), 'MBE': np.float64(-0.041401603602447365), 'NSE': np.float64(-162.22307964854141)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.33173371078377, 'RMSE': np.float64(0.16028410843385707), 'MBE': np.float64(-0.03580923294644811), 'NSE': np.float64(-156.60356269258506)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.3328717595490537, 'RMSE': np.float64(0.1601475694060887), 'MBE': np.float64(-0.024385706531263752), 'NSE': np.float64(-150.7279877423842)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# {'R2': 0.4230023776885735, 'RMSE': np.float64(0.14893703397066677), 'MBE': np.float64(-0.005901155460922322), 'NSE': np.float64(-161.75826998123307)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.34880669593076374, 'RMSE': np.float64(0.15822337794869848), 'MBE': np.float64(0.002402432767516887), 'NSE': np.float64(-149.54926414703556)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.3535108246253803, 'RMSE': np.float64(0.157650850413413), 'MBE': np.float64(-0.03721167419185453), 'NSE': np.float64(-160.43954568629727)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# {'R2': 0.4255613709104312, 'RMSE': np.float64(0.1486063979650682), 'MBE': np.float64(-0.011817708218071639), 'NSE': np.float64(-163.4627897856432)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': -0.009586315571288972, 'RMSE': np.float64(0.19700961244027781), 'MBE': np.float64(0.09226967656099021), 'NSE': np.float64(-167.5020418396275)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.49181226286054636, 'RMSE': np.float64(0.13977444598288896), 'MBE': np.float64(-0.004560098548229703), 'NSE': np.float64(-160.77018957745236)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.4844908841920611, 'RMSE': np.float64(0.14077769941342855), 'MBE': np.float64(-0.03697243293521184), 'NSE': np.float64(-169.8415979295)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.3720470444192181, 'RMSE': np.float64(0.1553743208914254), 'MBE': np.float64(-0.042348958492075074), 'NSE': np.float64(-161.42012158187976)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.4429166326873666, 'RMSE': np.float64(0.1463442910271886), 'MBE': np.float64(0.012407231635326135), 'NSE': np.float64(-160.10264200093053)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.4505935596420845, 'RMSE': np.float64(0.14533243900519158), 'MBE': np.float64(-0.04631499884535191), 'NSE': np.float64(-175.0744818008489)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.2834980177627797, 'RMSE': np.float64(0.16596801015515672), 'MBE': np.float64(0.018673654093875173), 'NSE': np.float64(-147.32981707819485)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.2886930104961928, 'RMSE': np.float64(0.16536524061076263), 'MBE': np.float64(0.05363231514125554), 'NSE': np.float64(-165.07715357836503)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.4103415423989819, 'RMSE': np.float64(0.15056220106164167), 'MBE': np.float64(-0.0078165729613186), 'NSE': np.float64(-163.3042690280594)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.19241491068977867, 'RMSE': np.float64(0.17620159481400186), 'MBE': np.float64(0.04324901343479911), 'NSE': np.float64(-148.1162682461063)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# {'R2': 0.3392164558113372, 'RMSE': np.float64(0.15938421159475918), 'MBE': np.float64(-0.018456119928583033), 'NSE': np.float64(-155.1612315776048)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.3736349633579886, 'RMSE': np.float64(0.15517774725096262), 'MBE': np.float64(-0.014509170186849425), 'NSE': np.float64(-158.64856918670415)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.4334197131292823, 'RMSE': np.float64(0.1475864270641723), 'MBE': np.float64(-0.03608156234272444), 'NSE': np.float64(-170.63361615078261)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.4738087429628328, 'RMSE': np.float64(0.14222878592654295), 'MBE': np.float64(0.02453419182925908), 'NSE': np.float64(-168.4924875052578)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.4915329735160575, 'RMSE': np.float64(0.13981284926229298), 'MBE': np.float64(-0.044265008290997825), 'NSE': np.float64(-174.3831698643592)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.4727549444789986, 'RMSE': np.float64(0.14237113484524966), 'MBE': np.float64(0.01046231650792777), 'NSE': np.float64(-171.76457892024177)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.4099655493767087, 'RMSE': np.float64(0.15061019606182605), 'MBE': np.float64(-0.06705632922166382), 'NSE': np.float64(-190.12268135326212)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.5055053018230381, 'RMSE': np.float64(0.13787848691718757), 'MBE': np.float64(-0.04455589118979824), 'NSE': np.float64(-179.36115310305158)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.44428164182032137, 'RMSE': np.float64(0.14616488896336766), 'MBE': np.float64(0.0007740934768979923), 'NSE': np.float64(-152.70993329494425)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.5537877465353596, 'RMSE': np.float64(0.13097440529545804), 'MBE': np.float64(0.0072688028369637435), 'NSE': np.float64(-181.58532415338647)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.43675224611287444, 'RMSE': np.float64(0.14715174727731276), 'MBE': np.float64(-0.009990236703825277), 'NSE': np.float64(-157.09061074868927)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.26211748318138617, 'RMSE': np.float64(0.1684260638485614), 'MBE': np.float64(-0.07612329526425361), 'NSE': np.float64(-167.67068062856765)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.633819123936507, 'RMSE': np.float64(0.11864884603891807), 'MBE': np.float64(-0.010111372468872493), 'NSE': np.float64(-206.72198791260442)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.5568549575835715, 'RMSE': np.float64(0.1305234776512046), 'MBE': np.float64(0.0070814654384346925), 'NSE': np.float64(-172.11609398691286)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.3541540373509776, 'RMSE': np.float64(0.15757240496383346), 'MBE': np.float64(-0.0006907662862901578), 'NSE': np.float64(-151.52682139174578)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.356925134780943, 'RMSE': np.float64(0.15723399774645896), 'MBE': np.float64(0.007454582952945338), 'NSE': np.float64(-152.22359373608643)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.44610372973380585, 'RMSE': np.float64(0.14592506969258331), 'MBE': np.float64(0.0037674231691407507), 'NSE': np.float64(-164.52451691784003)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.3052280581142828, 'RMSE': np.float64(0.1634318981088412), 'MBE': np.float64(0.012544872104435962), 'NSE': np.float64(-148.3328189461252)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.30352575025775896, 'RMSE': np.float64(0.1636319934060836), 'MBE': np.float64(0.025290603239348824), 'NSE': np.float64(-150.2747192440805)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.39573184565636166, 'RMSE': np.float64(0.15241599392269575), 'MBE': np.float64(-0.022134939732632277), 'NSE': np.float64(-163.4859677217538)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.4486891658871923, 'RMSE': np.float64(0.14558410220323537), 'MBE': np.float64(4.8585740691937665e-05), 'NSE': np.float64(-160.68831573482072)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.5219326630282649, 'RMSE': np.float64(0.13556894775358172), 'MBE': np.float64(0.006458525730806754), 'NSE': np.float64(-165.04860484441082)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
# {'R2': 0.5855878582964982, 'RMSE': np.float64(0.12622108951144861), 'MBE': np.float64(-0.04061964092661259), 'NSE': np.float64(-194.9310613975315)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.45843797111200246, 'RMSE': np.float64(0.14429118241178232), 'MBE': np.float64(0.019911851849332925), 'NSE': np.float64(-160.66429017506653)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.551488088294388, 'RMSE': np.float64(0.13131147503484222), 'MBE': np.float64(-0.03335472612929941), 'NSE': np.float64(-183.9380223929388)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
# {'R2': 0.47128112430186786, 'RMSE': np.float64(0.1425699826279855), 'MBE': np.float64(-0.05613204797503727), 'NSE': np.float64(-189.3274219103556)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.516641690951978, 'RMSE': np.float64(0.13631708272020454), 'MBE': np.float64(0.04809026059128391), 'NSE': np.float64(-180.4108725465885)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# {'R2': 0.5850252509442141, 'RMSE': np.float64(0.12630673954475033), 'MBE': np.float64(-0.022914839153655175), 'NSE': np.float64(-183.43521517382842)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# {'R2': 0.5725424627191497, 'RMSE': np.float64(0.1281923705582518), 'MBE': np.float64(-0.015697134793490365), 'NSE': np.float64(-179.23983008200054)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.5185811532078936, 'RMSE': np.float64(0.13604332351147583), 'MBE': np.float64(-0.03642856924193182), 'NSE': np.float64(-171.88235195919083)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# {'R2': 0.5070569541479865, 'RMSE': np.float64(0.1376619956513276), 'MBE': np.float64(0.005309651540490481), 'NSE': np.float64(-164.34460145981154)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step
# {'R2': 0.5781580871505241, 'RMSE': np.float64(0.12734753789191355), 'MBE': np.float64(-0.023080670840500642), 'NSE': np.float64(-180.25565662605786)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units        R2      RMSE       MBE  \
# 0       10         0.0001      adam          16  0.149148  0.180860  0.060445
# 1       10         0.0001      adam          32  0.351898  0.157847 -0.024353
# 2       10         0.0001      adam          64  0.339199  0.159386 -0.025851
# 3       10         0.0001   rmsprop          16  0.343926  0.158815 -0.007556
# 4       10         0.0001   rmsprop          32  0.289202  0.165306  0.009848
# 5       10         0.0001   rmsprop          64  0.309446  0.162935 -0.041402
# 6       10         0.0010      adam          16  0.331734  0.160284 -0.035809
# 7       10         0.0010      adam          32  0.332872  0.160148 -0.024386
# 8       10         0.0010      adam          64  0.423002  0.148937 -0.005901
# 9       10         0.0010   rmsprop          16  0.348807  0.158223  0.002402
# 10      10         0.0010   rmsprop          32  0.353511  0.157651 -0.037212
# 11      10         0.0010   rmsprop          64  0.425561  0.148606 -0.011818
# 12      10         0.0100      adam          16 -0.009586  0.197010  0.092270
# 13      10         0.0100      adam          32  0.491812  0.139774 -0.004560
# 14      10         0.0100      adam          64  0.484491  0.140778 -0.036972
# 15      10         0.0100   rmsprop          16  0.372047  0.155374 -0.042349
# 16      10         0.0100   rmsprop          32  0.442917  0.146344  0.012407
# 17      10         0.0100   rmsprop          64  0.450594  0.145332 -0.046315
# 18      30         0.0001      adam          16  0.283498  0.165968  0.018674
# 19      30         0.0001      adam          32  0.288693  0.165365  0.053632
# 20      30         0.0001      adam          64  0.410342  0.150562 -0.007817
# 21      30         0.0001   rmsprop          16  0.192415  0.176202  0.043249
# 22      30         0.0001   rmsprop          32  0.339216  0.159384 -0.018456
# 23      30         0.0001   rmsprop          64  0.373635  0.155178 -0.014509
# 24      30         0.0010      adam          16  0.433420  0.147586 -0.036082
# 25      30         0.0010      adam          32  0.473809  0.142229  0.024534
# 26      30         0.0010      adam          64  0.491533  0.139813 -0.044265
# 27      30         0.0010   rmsprop          16  0.472755  0.142371  0.010462
# 28      30         0.0010   rmsprop          32  0.409966  0.150610 -0.067056
# 29      30         0.0010   rmsprop          64  0.505505  0.137878 -0.044556
# 30      30         0.0100      adam          16  0.444282  0.146165  0.000774
# 31      30         0.0100      adam          32  0.553788  0.130974  0.007269
# 32      30         0.0100      adam          64  0.436752  0.147152 -0.009990
# 33      30         0.0100   rmsprop          16  0.262117  0.168426 -0.076123
# 34      30         0.0100   rmsprop          32  0.633819  0.118649 -0.010111
# 35      30         0.0100   rmsprop          64  0.556855  0.130523  0.007081
# 36      50         0.0001      adam          16  0.354154  0.157572 -0.000691
# 37      50         0.0001      adam          32  0.356925  0.157234  0.007455
# 38      50         0.0001      adam          64  0.446104  0.145925  0.003767
# 39      50         0.0001   rmsprop          16  0.305228  0.163432  0.012545
# 40      50         0.0001   rmsprop          32  0.303526  0.163632  0.025291
# 41      50         0.0001   rmsprop          64  0.395732  0.152416 -0.022135
# 42      50         0.0010      adam          16  0.448689  0.145584  0.000049
# 43      50         0.0010      adam          32  0.521933  0.135569  0.006459
# 44      50         0.0010      adam          64  0.585588  0.126221 -0.040620
# 45      50         0.0010   rmsprop          16  0.458438  0.144291  0.019912
# 46      50         0.0010   rmsprop          32  0.551488  0.131311 -0.033355
# 47      50         0.0010   rmsprop          64  0.471281  0.142570 -0.056132
# 48      50         0.0100      adam          16  0.516642  0.136317  0.048090
# 49      50         0.0100      adam          32  0.585025  0.126307 -0.022915
# 50      50         0.0100      adam          64  0.572542  0.128192 -0.015697
# 51      50         0.0100   rmsprop          16  0.518581  0.136043 -0.036429
# 52      50         0.0100   rmsprop          32  0.507057  0.137662  0.005310
# 53      50         0.0100   rmsprop          64  0.578158  0.127348 -0.023081
#
#            NSE
# 0  -157.693312
# 1  -161.636260
# 2  -157.840619
# 3  -157.917757
# 4  -151.323300
# 5  -162.223080
# 6  -156.603563
# 7  -150.727988
# 8  -161.758270
# 9  -149.549264
# 10 -160.439546
# 11 -163.462790
# 12 -167.502042
# 13 -160.770190
# 14 -169.841598
# 15 -161.420122
# 16 -160.102642
# 17 -175.074482
# 18 -147.329817
# 19 -165.077154
# 20 -163.304269
# 21 -148.116268
# 22 -155.161232
# 23 -158.648569
# 24 -170.633616
# 25 -168.492488
# 26 -174.383170
# 27 -171.764579
# 28 -190.122681
# 29 -179.361153
# 30 -152.709933
# 31 -181.585324
# 32 -157.090611
# 33 -167.670681
# 34 -206.721988
# 35 -172.116094
# 36 -151.526821
# 37 -152.223594
# 38 -164.524517
# 39 -148.332819
# 40 -150.274719
# 41 -163.485968
# 42 -160.688316
# 43 -165.048605
# 44 -194.931061
# 45 -160.664290
# 46 -183.938022
# 47 -189.327422
# 48 -180.410873
# 49 -183.435215
# 50 -179.239830
# 51 -171.882352
# 52 -164.344601
# 53 -180.255657

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}"
best_model = models[best_model_name]

best_model.save("us_embassy_2.keras")

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0168
# Test Loss: 0.014077547937631607

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# Testing Metrics:
# Test R²: 0.6338
# Test RMSE: 0.1186
# Test MBE: -0.0101
# Test NSE: -206.7220

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
#  30/265 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 265/265 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("us_embassy_2 results.csv", index=False)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.initializers import glorot_uniform

model = load_model("us_embassy_2.keras")


# Fungsi untuk me-reset bobot model
def reset_weights(model):
    for layer in model.layers:
        # Reset weights untuk layer yang memiliki weights (Dense, Conv2D, LSTM, dll.)
        if hasattr(layer, 'weights'):
            for weight in layer.weights:
                # Dapatkan initializer yang sesuai
                if 'kernel' in weight.name:
                    initializer = layer.kernel_initializer
                elif 'bias' in weight.name:
                    initializer = layer.bias_initializer
                elif 'recurrent_kernel' in weight.name:
                    initializer = layer.recurrent_initializer
                else:
                    continue  # Lewati jika tidak dikenali
                
                # Reset nilai weights
                new_weights = initializer(weight.shape)
                weight.assign(new_weights)
# Reset bobot model
reset_weights(model)


class R2History(Callback):
    def __init__(self, val_gen):
        self.val_gen = val_gen
        self.r2_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_pred = self.model.predict(self.val_gen)

        val_true_list = []
        for i in range(len(test_gen)):  
            _, y =  val_gen[i]  # Ambil hanya nilai target dari generator
            val_true_list.append(y)
        
        val_true = np.hstack(val_true_list)  # Gabungkan list ke array numpy
                        
        r2 = r2_score(val_true, val_pred)
        self.r2_scores.append(r2)

r2_callback = R2History(val_gen)

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=100, callbacks=[r2_callback])
# Out:
# Epoch 1/100
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step    - loss: 54
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 54.0845 - val_loss: 0.0873
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0222 - val_loss: 0.0366
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0168 - val_loss: 0.0176
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0160 - val_loss: 0.0122
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0164 - val_loss: 0.0109
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0146 - val_loss: 0.0111
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0131 - val_loss: 0.0146
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0137 - val_loss: 0.0099
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0146
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0127 - val_loss: 0.0335
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0117 - val_loss: 0.0113
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0103 - val_loss: 0.0185
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0113 - val_loss: 0.0131
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0129 - val_loss: 0.0127
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0102 - val_loss: 0.0084
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0110 - val_loss: 0.0157
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0106 - val_loss: 0.0145
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0114 - val_loss: 0.0157
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0091 - val_loss: 0.0103
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0104 - val_loss: 0.0125
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0087 - val_loss: 0.0266
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0107 - val_loss: 0.0095
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0107 - val_loss: 0.0101
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0111 - val_loss: 0.0102
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0103 - val_loss: 0.0087
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0094 - val_loss: 0.0191
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0088 - val_loss: 0.0097
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0107 - val_loss: 0.0158
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0098 - val_loss: 0.0141
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0096 - val_loss: 0.0118
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0132 - val_loss: 0.0134
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0088 - val_loss: 0.0109
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0095 - val_loss: 0.0126
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0102 - val_loss: 0.0152
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0100 - val_loss: 0.0251
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0086 - val_loss: 0.0134
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0091 - val_loss: 0.0098
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0075 - val_loss: 0.0085
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0090 - val_loss: 0.0086
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0099 - val_loss: 0.0100
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0084 - val_loss: 0.0116
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0095 - val_loss: 0.0170
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0100 - val_loss: 0.0119
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0076 - val_loss: 0.0136
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0082 - val_loss: 0.0166
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0091 - val_loss: 0.0085
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0084 - val_loss: 0.0127
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0084 - val_loss: 0.0128
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0085 - val_loss: 0.0163
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0082 - val_loss: 0.0104
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0086 - val_loss: 0.0109
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0071 - val_loss: 0.0096
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0081 - val_loss: 0.0136
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0088 - val_loss: 0.0112
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0088 - val_loss: 0.0153
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0086 - val_loss: 0.0101
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0072 - val_loss: 0.0101
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0087 - val_loss: 0.0107
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0067 - val_loss: 0.0096
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0070 - val_loss: 0.0141
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0074 - val_loss: 0.0096
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0072 - val_loss: 0.0106
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0083 - val_loss: 0.0092
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0090 - val_loss: 0.0090
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0085 - val_loss: 0.0098
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0083 - val_loss: 0.0095
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0077 - val_loss: 0.0161
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0089 - val_loss: 0.0144
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0093 - val_loss: 0.0103
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0090 - val_loss: 0.0147
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0089 - val_loss: 0.0117
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0076 - val_loss: 0.0086
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0064 - val_loss: 0.0147
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0077 - val_loss: 0.0094
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0085 - val_loss: 0.0096
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0077 - val_loss: 0.0095
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0075 - val_loss: 0.0093
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0086 - val_loss: 0.0104
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0075 - val_loss: 0.0090
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0075 - val_loss: 0.0129
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0080 - val_loss: 0.0092
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0072 - val_loss: 0.0119
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0076 - val_loss: 0.0112
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0075 - val_loss: 0.0131

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
r2_scores = r2_callback.r2_scores

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i] 
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  
test_pred = model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 28/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
#
# Testing Metrics:
# Test R²: 0.6311
# Test RMSE: 0.1185
# Test MBE: 0.0060
# Test NSE: -182.0613
