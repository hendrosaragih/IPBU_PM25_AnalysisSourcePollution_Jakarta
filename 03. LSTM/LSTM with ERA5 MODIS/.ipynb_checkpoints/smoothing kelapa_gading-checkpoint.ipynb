# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\kelapa_gading.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()
# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity   precip  windspeed  \
# 14     52.083333  2022-01-15  27.0  24.4      86.7    4.747       16.6
# 15     52.991667  2022-01-16  27.2  25.3      89.8    9.154       11.8
# 16     53.900000  2022-01-17  27.8  24.8      84.5   25.273       19.5
# 17     36.533333  2022-01-18  26.1  24.7      92.2  106.769       18.4
# 18     37.250000  2022-01-19  27.1  24.2      84.9   73.133       27.7
# ...          ...         ...   ...   ...       ...      ...        ...
# 1088   46.282540  2024-12-24  27.2  23.9      82.9   17.956       24.8
# 1089   49.003175  2024-12-25  27.2  24.4      84.9    5.317       12.4
# 1090   51.723810  2024-12-26  28.5  23.6      75.9    1.660       24.8
# 1091   54.444444  2024-12-27  29.0  23.6      73.5    0.000       14.9
# 1092   50.354167  2024-12-28  29.6  22.6      67.3    0.004       21.2
#
#            AOD
# 14    0.534400
# 15    0.511400
# 16    0.468000
# 17    0.404200
# 18    0.395143
# ...        ...
# 1088  0.478043
# 1089  0.530371
# 1090  0.580257
# 1091  0.676929
# 1092  0.820386
#
# [1079 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(0.2),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model

def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}"
                    print(f"\nTraining model dengan {config_name}")
                    
                    model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate)
                    model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0)
                    
                    metrics = evaluate_model(model, test_gen)
                    print(metrics)
                    
                    results.append({
                        'epochs': epochs,
                        'learning_rate': learning_rate,
                        'optimizer': optimizer,
                        'lstm_units': lstm_units,
                        'R2': metrics['R2'],
                        'RMSE': metrics['RMSE'],
                        'MBE': metrics['MBE'],
                        'NSE': metrics['NSE']
                    })
                    models[config_name] = model
    
    return results, models

# %%
param_grid = {
    'epochs': [10, 30, 50],
    'learning_rate': [0.0001, 0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64]
}

grid_results, models = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_16
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# {'R2': 0.30821331375307914, 'RMSE': np.float64(0.15434427162352315), 'MBE': np.float64(0.028144384695416608), 'NSE': np.float64(-146.01646160491845)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.4594674864547792, 'RMSE': np.float64(0.13643171140071694), 'MBE': np.float64(-0.027011277318106996), 'NSE': np.float64(-159.40299314091078)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.5264952977455222, 'RMSE': np.float64(0.12769284522241195), 'MBE': np.float64(-0.022773917956244928), 'NSE': np.float64(-169.25434619156914)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.29443547856048313, 'RMSE': np.float64(0.15587367799135088), 'MBE': np.float64(0.03844844714196815), 'NSE': np.float64(-148.52206302176864)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.3492426174211273, 'RMSE': np.float64(0.14969730012263488), 'MBE': np.float64(0.04687388461194875), 'NSE': np.float64(-157.18648312792894)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.4106471130375411, 'RMSE': np.float64(0.14245973214693766), 'MBE': np.float64(-0.06261582741819156), 'NSE': np.float64(-179.30009665603598)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.43761875701600694, 'RMSE': np.float64(0.13916173332676524), 'MBE': np.float64(-0.020147079877105567), 'NSE': np.float64(-153.13099041952637)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step
# {'R2': 0.5003994625973263, 'RMSE': np.float64(0.13116436595951037), 'MBE': np.float64(-0.03435412563327478), 'NSE': np.float64(-167.38901677558763)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.5222158026093333, 'RMSE': np.float64(0.12826858580005726), 'MBE': np.float64(-0.05876583619626546), 'NSE': np.float64(-190.76629419799033)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.45696356855755993, 'RMSE': np.float64(0.13674734375694836), 'MBE': np.float64(0.02319343385579035), 'NSE': np.float64(-157.55090067888935)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.198543447412866, 'RMSE': np.float64(0.16612860099549537), 'MBE': np.float64(-0.12108545941925707), 'NSE': np.float64(-252.41558092445038)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.5901873874544408, 'RMSE': np.float64(0.11879470296151363), 'MBE': np.float64(-0.020167856543917607), 'NSE': np.float64(-175.19061691805365)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.6025829947784873, 'RMSE': np.float64(0.11698431569729162), 'MBE': np.float64(-0.006042512520141903), 'NSE': np.float64(-172.23568298223813)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.6135228107701411, 'RMSE': np.float64(0.11536294886357358), 'MBE': np.float64(0.017136301097478983), 'NSE': np.float64(-167.471841065126)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.5562386724267002, 'RMSE': np.float64(0.12361726817735817), 'MBE': np.float64(-0.052078979921091305), 'NSE': np.float64(-188.78154056361848)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.5512575087700163, 'RMSE': np.float64(0.12430912603578816), 'MBE': np.float64(0.007046182183970812), 'NSE': np.float64(-157.1744959192006)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.6006320528814237, 'RMSE': np.float64(0.11727110537575473), 'MBE': np.float64(-0.009617572647528315), 'NSE': np.float64(-164.20913769200646)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.4640928954133072, 'RMSE': np.float64(0.13584672506641166), 'MBE': np.float64(-0.06350766191564335), 'NSE': np.float64(-180.12746301008568)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.3581424009001346, 'RMSE': np.float64(0.14867014309990903), 'MBE': np.float64(0.028165176930606023), 'NSE': np.float64(-148.4632503539753)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.5160455251866407, 'RMSE': np.float64(0.12909418222478364), 'MBE': np.float64(0.004930175037420167), 'NSE': np.float64(-160.19414617558454)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.5603511018858204, 'RMSE': np.float64(0.12304314134442425), 'MBE': np.float64(-0.02078745572257343), 'NSE': np.float64(-175.78567998407567)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step
# {'R2': 0.4907434106618148, 'RMSE': np.float64(0.13242584242083807), 'MBE': np.float64(0.008566426449641019), 'NSE': np.float64(-159.59029222472617)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.425559243891928, 'RMSE': np.float64(0.14064588766920127), 'MBE': np.float64(-0.05310836881676662), 'NSE': np.float64(-171.4191102744347)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# {'R2': 0.5081878867928538, 'RMSE': np.float64(0.1301379695184152), 'MBE': np.float64(-0.040334214717700746), 'NSE': np.float64(-175.18733350424662)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.46499055796080724, 'RMSE': np.float64(0.13573290345035136), 'MBE': np.float64(0.018064737517336067), 'NSE': np.float64(-154.8946689530559)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.6974257762642057, 'RMSE': np.float64(0.10207523294407267), 'MBE': np.float64(-0.016256918238276317), 'NSE': np.float64(-189.06246810264471)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.7123808342331819, 'RMSE': np.float64(0.09952067820565316), 'MBE': np.float64(0.004676015271963122), 'NSE': np.float64(-188.6396762771748)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# {'R2': 0.5175283538166067, 'RMSE': np.float64(0.12889625926422824), 'MBE': np.float64(0.013441227462648114), 'NSE': np.float64(-156.83079130092477)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# {'R2': 0.6292769438780663, 'RMSE': np.float64(0.11298719163687095), 'MBE': np.float64(-0.04517174192161648), 'NSE': np.float64(-198.59677526989293)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.6830536306718842, 'RMSE': np.float64(0.10447137396825384), 'MBE': np.float64(-4.925169884214623e-05), 'NSE': np.float64(-180.9049199567037)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# {'R2': 0.604523707185864, 'RMSE': np.float64(0.11669833050153576), 'MBE': np.float64(-0.013300220270761257), 'NSE': np.float64(-162.97045901966675)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# {'R2': 0.5853559375010229, 'RMSE': np.float64(0.11949291100600341), 'MBE': np.float64(0.023664150195229064), 'NSE': np.float64(-171.58243020477227)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.6298199162036587, 'RMSE': np.float64(0.11290441906981237), 'MBE': np.float64(0.03879861286494324), 'NSE': np.float64(-180.92280210718536)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.6668137909870396, 'RMSE': np.float64(0.10711441601419648), 'MBE': np.float64(-0.010567626204169851), 'NSE': np.float64(-173.1398797733809)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.773542875523562, 'RMSE': np.float64(0.08830746340317995), 'MBE': np.float64(-0.007828698588057587), 'NSE': np.float64(-213.57461226849856)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.6536027261186135, 'RMSE': np.float64(0.10921735345878666), 'MBE': np.float64(-0.02714776528248091), 'NSE': np.float64(-179.61056521633864)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.43674927715027756, 'RMSE': np.float64(0.13926926855745905), 'MBE': np.float64(-0.016549519885938016), 'NSE': np.float64(-155.77870716966194)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# {'R2': 0.5136982313590801, 'RMSE': np.float64(0.12940687220818678), 'MBE': np.float64(-0.017436772832336158), 'NSE': np.float64(-163.72855125266832)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.5667805296821564, 'RMSE': np.float64(0.12214013602403481), 'MBE': np.float64(-0.025722242583196008), 'NSE': np.float64(-174.1491714109872)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# {'R2': 0.46136334213541286, 'RMSE': np.float64(0.13619224196295793), 'MBE': np.float64(-0.0009223839045633007), 'NSE': np.float64(-152.86785225982626)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
# {'R2': 0.5315501378688032, 'RMSE': np.float64(0.12700943191998104), 'MBE': np.float64(-0.0003478729708153655), 'NSE': np.float64(-162.9325410870264)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.5309258599962543, 'RMSE': np.float64(0.12709403305432232), 'MBE': np.float64(-0.03781554416766752), 'NSE': np.float64(-177.7763109029253)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step
# {'R2': 0.6774649029292357, 'RMSE': np.float64(0.10538842295769901), 'MBE': np.float64(-0.01864377022511868), 'NSE': np.float64(-185.58611459240825)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.66395051138957, 'RMSE': np.float64(0.1075736823587541), 'MBE': np.float64(-0.03484806687806915), 'NSE': np.float64(-191.56717356383058)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.6899172975874733, 'RMSE': np.float64(0.10333398690525057), 'MBE': np.float64(-0.0385422682389567), 'NSE': np.float64(-204.38362696005026)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# {'R2': 0.46545925960659584, 'RMSE': np.float64(0.1356734351777125), 'MBE': np.float64(-0.08037785943597056), 'NSE': np.float64(-206.03047404697182)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.6667876257602044, 'RMSE': np.float64(0.10711862179747167), 'MBE': np.float64(-0.023069935083495485), 'NSE': np.float64(-187.9476445192739)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.7233675482467947, 'RMSE': np.float64(0.09760138460056153), 'MBE': np.float64(-0.03723018908066481), 'NSE': np.float64(-215.66927845255432)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.6012874334173197, 'RMSE': np.float64(0.11717484232077073), 'MBE': np.float64(-0.021912538318597904), 'NSE': np.float64(-166.32809322203008)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# {'R2': 0.7608142651165977, 'RMSE': np.float64(0.09075531178558445), 'MBE': np.float64(-0.02769258509653663), 'NSE': np.float64(-216.4638961289874)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5994412550920738, 'RMSE': np.float64(0.1174458092209047), 'MBE': np.float64(0.034646497597339086), 'NSE': np.float64(-172.758012197926)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.6266840146760229, 'RMSE': np.float64(0.11338163338405403), 'MBE': np.float64(-0.0321543005670357), 'NSE': np.float64(-175.39325331900275)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.621884246265433, 'RMSE': np.float64(0.11410818613016822), 'MBE': np.float64(-0.04926564913909772), 'NSE': np.float64(-188.86827380762224)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.790265396213301, 'RMSE': np.float64(0.08498444856790964), 'MBE': np.float64(-0.002197250971259806), 'NSE': np.float64(-225.65392925611795)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units        R2      RMSE       MBE  \
# 0       10         0.0001      adam          16  0.308213  0.154344  0.028144
# 1       10         0.0001      adam          32  0.459467  0.136432 -0.027011
# 2       10         0.0001      adam          64  0.526495  0.127693 -0.022774
# 3       10         0.0001   rmsprop          16  0.294435  0.155874  0.038448
# 4       10         0.0001   rmsprop          32  0.349243  0.149697  0.046874
# 5       10         0.0001   rmsprop          64  0.410647  0.142460 -0.062616
# 6       10         0.0010      adam          16  0.437619  0.139162 -0.020147
# 7       10         0.0010      adam          32  0.500399  0.131164 -0.034354
# 8       10         0.0010      adam          64  0.522216  0.128269 -0.058766
# 9       10         0.0010   rmsprop          16  0.456964  0.136747  0.023193
# 10      10         0.0010   rmsprop          32  0.198543  0.166129 -0.121085
# 11      10         0.0010   rmsprop          64  0.590187  0.118795 -0.020168
# 12      10         0.0100      adam          16  0.602583  0.116984 -0.006043
# 13      10         0.0100      adam          32  0.613523  0.115363  0.017136
# 14      10         0.0100      adam          64  0.556239  0.123617 -0.052079
# 15      10         0.0100   rmsprop          16  0.551258  0.124309  0.007046
# 16      10         0.0100   rmsprop          32  0.600632  0.117271 -0.009618
# 17      10         0.0100   rmsprop          64  0.464093  0.135847 -0.063508
# 18      30         0.0001      adam          16  0.358142  0.148670  0.028165
# 19      30         0.0001      adam          32  0.516046  0.129094  0.004930
# 20      30         0.0001      adam          64  0.560351  0.123043 -0.020787
# 21      30         0.0001   rmsprop          16  0.490743  0.132426  0.008566
# 22      30         0.0001   rmsprop          32  0.425559  0.140646 -0.053108
# 23      30         0.0001   rmsprop          64  0.508188  0.130138 -0.040334
# 24      30         0.0010      adam          16  0.464991  0.135733  0.018065
# 25      30         0.0010      adam          32  0.697426  0.102075 -0.016257
# 26      30         0.0010      adam          64  0.712381  0.099521  0.004676
# 27      30         0.0010   rmsprop          16  0.517528  0.128896  0.013441
# 28      30         0.0010   rmsprop          32  0.629277  0.112987 -0.045172
# 29      30         0.0010   rmsprop          64  0.683054  0.104471 -0.000049
# 30      30         0.0100      adam          16  0.604524  0.116698 -0.013300
# 31      30         0.0100      adam          32  0.585356  0.119493  0.023664
# 32      30         0.0100      adam          64  0.629820  0.112904  0.038799
# 33      30         0.0100   rmsprop          16  0.666814  0.107114 -0.010568
# 34      30         0.0100   rmsprop          32  0.773543  0.088307 -0.007829
# 35      30         0.0100   rmsprop          64  0.653603  0.109217 -0.027148
# 36      50         0.0001      adam          16  0.436749  0.139269 -0.016550
# 37      50         0.0001      adam          32  0.513698  0.129407 -0.017437
# 38      50         0.0001      adam          64  0.566781  0.122140 -0.025722
# 39      50         0.0001   rmsprop          16  0.461363  0.136192 -0.000922
# 40      50         0.0001   rmsprop          32  0.531550  0.127009 -0.000348
# 41      50         0.0001   rmsprop          64  0.530926  0.127094 -0.037816
# 42      50         0.0010      adam          16  0.677465  0.105388 -0.018644
# 43      50         0.0010      adam          32  0.663951  0.107574 -0.034848
# 44      50         0.0010      adam          64  0.689917  0.103334 -0.038542
# 45      50         0.0010   rmsprop          16  0.465459  0.135673 -0.080378
# 46      50         0.0010   rmsprop          32  0.666788  0.107119 -0.023070
# 47      50         0.0010   rmsprop          64  0.723368  0.097601 -0.037230
# 48      50         0.0100      adam          16  0.601287  0.117175 -0.021913
# 49      50         0.0100      adam          32  0.760814  0.090755 -0.027693
# 50      50         0.0100      adam          64  0.599441  0.117446  0.034646
# 51      50         0.0100   rmsprop          16  0.626684  0.113382 -0.032154
# 52      50         0.0100   rmsprop          32  0.621884  0.114108 -0.049266
# 53      50         0.0100   rmsprop          64  0.790265  0.084984 -0.002197
#
#            NSE
# 0  -146.016462
# 1  -159.402993
# 2  -169.254346
# 3  -148.522063
# 4  -157.186483
# 5  -179.300097
# 6  -153.130990
# 7  -167.389017
# 8  -190.766294
# 9  -157.550901
# 10 -252.415581
# 11 -175.190617
# 12 -172.235683
# 13 -167.471841
# 14 -188.781541
# 15 -157.174496
# 16 -164.209138
# 17 -180.127463
# 18 -148.463250
# 19 -160.194146
# 20 -175.785680
# 21 -159.590292
# 22 -171.419110
# 23 -175.187334
# 24 -154.894669
# 25 -189.062468
# 26 -188.639676
# 27 -156.830791
# 28 -198.596775
# 29 -180.904920
# 30 -162.970459
# 31 -171.582430
# 32 -180.922802
# 33 -173.139880
# 34 -213.574612
# 35 -179.610565
# 36 -155.778707
# 37 -163.728551
# 38 -174.149171
# 39 -152.867852
# 40 -162.932541
# 41 -177.776311
# 42 -185.586115
# 43 -191.567174
# 44 -204.383627
# 45 -206.030474
# 46 -187.947645
# 47 -215.669278
# 48 -166.328093
# 49 -216.463896
# 50 -172.758012
# 51 -175.393253
# 52 -188.868274
# 53 -225.653929

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}"
best_model = models[best_model_name]

best_model.save("kelapa_gading.keras")

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069
# Test Loss: 0.007222356740385294

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# Testing Metrics:
# Test R²: 0.7903
# Test RMSE: 0.0850
# Test MBE: -0.0022
# Test NSE: -225.6539

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
#  24/264 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("kelapa_gading results.csv", index=False)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.initializers import glorot_uniform

model = load_model("kelapa_gading.keras")


# Fungsi untuk me-reset bobot model
def reset_weights(model):
    for layer in model.layers:
        # Reset weights untuk layer yang memiliki weights (Dense, Conv2D, LSTM, dll.)
        if hasattr(layer, 'weights'):
            for weight in layer.weights:
                # Dapatkan initializer yang sesuai
                if 'kernel' in weight.name:
                    initializer = layer.kernel_initializer
                elif 'bias' in weight.name:
                    initializer = layer.bias_initializer
                elif 'recurrent_kernel' in weight.name:
                    initializer = layer.recurrent_initializer
                else:
                    continue  # Lewati jika tidak dikenali
                
                # Reset nilai weights
                new_weights = initializer(weight.shape)
                weight.assign(new_weights)
# Reset bobot model
reset_weights(model)


class R2History(Callback):
    def __init__(self, val_gen):
        self.val_gen = val_gen
        self.r2_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_pred = self.model.predict(self.val_gen)

        val_true_list = []
        for i in range(len(test_gen)):  
            _, y =  val_gen[i]  # Ambil hanya nilai target dari generator
            val_true_list.append(y)
        
        val_true = np.hstack(val_true_list)  # Gabungkan list ke array numpy
                        
        r2 = r2_score(val_true, val_pred)
        self.r2_scores.append(r2)

r2_callback = R2History(val_gen)

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=100, callbacks=[r2_callback])
# Out:
# Epoch 1/100
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step   - loss: 8194111285609942220
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 81287308057851723776.0000 - val_loss: 0.2528
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 52
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 53.1249 - val_loss: 0.0198
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1952 - val_loss: 0.0274
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 22
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 22.5952 - val_loss: 0.0187
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0263 - val_loss: 0.0168
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0236 - val_loss: 0.0445
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0191 - val_loss: 0.0128
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0166 - val_loss: 0.0323
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0160 - val_loss: 0.0115
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0147 - val_loss: 0.0135
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0133 - val_loss: 0.0093
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0129 - val_loss: 0.0120
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0125 - val_loss: 0.0119
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0121 - val_loss: 0.0120
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0130 - val_loss: 0.0117
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0122 - val_loss: 0.0134
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0140 - val_loss: 0.0169
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0110 - val_loss: 0.0189
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0109 - val_loss: 0.0160
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0120 - val_loss: 0.0107
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0109 - val_loss: 0.0198
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0111 - val_loss: 0.0087
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0127 - val_loss: 0.0101
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0107 - val_loss: 0.0101
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0084 - val_loss: 0.0120
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0113 - val_loss: 0.0106
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0106 - val_loss: 0.0151
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0127 - val_loss: 0.0143
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0106 - val_loss: 0.0097
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0113 - val_loss: 0.0097
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0110 - val_loss: 0.0109
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0107 - val_loss: 0.0117
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0106 - val_loss: 0.0138
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0100 - val_loss: 0.0150
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0115 - val_loss: 0.0094
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0101 - val_loss: 0.0186
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0109 - val_loss: 0.0115
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0100 - val_loss: 0.0128
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0102 - val_loss: 0.0193
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0101 - val_loss: 0.0169
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0098 - val_loss: 0.0300
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0103 - val_loss: 0.0169
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0093 - val_loss: 0.0173
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0101 - val_loss: 0.0140
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0101 - val_loss: 0.0117
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0094 - val_loss: 0.0104
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0097 - val_loss: 0.0141
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0098 - val_loss: 0.0101
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0090 - val_loss: 0.0110
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0098 - val_loss: 0.0099
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0091 - val_loss: 0.0149
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0100 - val_loss: 0.0145
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0103 - val_loss: 0.0111
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0107 - val_loss: 0.0106
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0111 - val_loss: 0.0121
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0114 - val_loss: 0.0103
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0094 - val_loss: 0.0145
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0092 - val_loss: 0.0139
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0102 - val_loss: 0.0165
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0094 - val_loss: 0.0187
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0094 - val_loss: 0.0121
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0096 - val_loss: 0.0135
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0090 - val_loss: 0.0110
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0096 - val_loss: 0.0114
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0082 - val_loss: 0.0126
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0098 - val_loss: 0.0110
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0100 - val_loss: 0.0123
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0092 - val_loss: 0.0168
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0082 - val_loss: 0.0125
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0101 - val_loss: 0.0151
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0073 - val_loss: 0.0105
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0098 - val_loss: 0.0105
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0095 - val_loss: 0.0116
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0100 - val_loss: 0.0144
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0087 - val_loss: 0.0183
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0086 - val_loss: 0.0110
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0090 - val_loss: 0.0123
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0093 - val_loss: 0.0107
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0083 - val_loss: 0.0188
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0095 - val_loss: 0.0116
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0088 - val_loss: 0.0112
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0096 - val_loss: 0.0123
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0091 - val_loss: 0.0110
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0088 - val_loss: 0.0116
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0084 - val_loss: 0.0115
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0085 - val_loss: 0.0183
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0093 - val_loss: 0.0151
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0089 - val_loss: 0.0129
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0087 - val_loss: 0.0159
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0088 - val_loss: 0.0117
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0082 - val_loss: 0.0138
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0076 - val_loss: 0.0133
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0074 - val_loss: 0.0135
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0085 - val_loss: 0.0181
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0076 - val_loss: 0.0119

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
r2_scores = r2_callback.r2_scores

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i] 
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  
test_pred = model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 12/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.5768
# Test RMSE: 0.1193
# Test MBE: -0.0512
# Test NSE: -187.3586
