# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\kebun_jeruk.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()
# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity   precip  windspeed  \
# 14     59.833333  2022-01-15  26.8  24.7      88.6    4.661       17.3
# 15     66.966667  2022-01-16  27.2  25.5      90.6    8.146       15.1
# 16     74.100000  2022-01-17  27.7  25.0      86.0    9.138       19.3
# 17     62.933333  2022-01-18  26.1  24.8      93.0  120.949       18.4
# 18     49.312500  2022-01-19  27.0  24.4      86.7   59.672       27.7
# ...          ...         ...   ...   ...       ...      ...        ...
# 1088   45.255556  2024-12-24  27.1  23.8      82.8   19.833       17.8
# 1089   48.244444  2024-12-25  27.1  24.3      85.2    6.582       15.2
# 1090   51.233333  2024-12-26  27.9  23.8      79.0    2.767       17.9
# 1091   54.222222  2024-12-27  28.7  23.7      75.3    0.000       16.7
# 1092   47.750000  2024-12-28  29.3  23.0      69.9    0.007       18.5
#
#            AOD
# 14    0.267067
# 15    0.229222
# 16    0.191378
# 17    0.153533
# 18    0.175924
# ...        ...
# 1088  0.355171
# 1089  0.385457
# 1090  0.393957
# 1091  0.380671
# 1092  0.363557
#
# [1079 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(0.2),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model

def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}"
                    print(f"\nTraining model dengan {config_name}")
                    
                    model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate)
                    model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0)
                    
                    metrics = evaluate_model(model, test_gen)
                    print(metrics)
                    
                    results.append({
                        'epochs': epochs,
                        'learning_rate': learning_rate,
                        'optimizer': optimizer,
                        'lstm_units': lstm_units,
                        'R2': metrics['R2'],
                        'RMSE': metrics['RMSE'],
                        'MBE': metrics['MBE'],
                        'NSE': metrics['NSE']
                    })
                    models[config_name] = model
    
    return results, models

# %%
param_grid = {
    'epochs': [10, 30, 50],
    'learning_rate': [0.0001, 0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64]
}

grid_results, models = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_16
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.085854561598803, 'RMSE': np.float64(0.18079505032619544), 'MBE': np.float64(0.05676205871519859), 'NSE': np.float64(-148.65190049423427)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.28957805128863556, 'RMSE': np.float64(0.1593811931150402), 'MBE': np.float64(0.027093054792650725), 'NSE': np.float64(-149.27442708002832)}
#
# Training model dengan epochs_10_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.40314844848438214, 'RMSE': np.float64(0.14608716187291618), 'MBE': np.float64(0.006720700964875309), 'NSE': np.float64(-158.43928847427313)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.18437871273109163, 'RMSE': np.float64(0.17077455578257625), 'MBE': np.float64(0.019825927061697567), 'NSE': np.float64(-139.06081217863422)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.1715273155382352, 'RMSE': np.float64(0.17211470832736409), 'MBE': np.float64(0.054388393811201995), 'NSE': np.float64(-150.89024654364343)}
#
# Training model dengan epochs_10_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.39321662920697853, 'RMSE': np.float64(0.14729761786666096), 'MBE': np.float64(-0.000951383613951936), 'NSE': np.float64(-155.85765865167517)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': -0.05034594939149373, 'RMSE': np.float64(0.19379611686338047), 'MBE': np.float64(0.11079501931601597), 'NSE': np.float64(-188.0079523981413)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step
# {'R2': 0.24251590411580348, 'RMSE': np.float64(0.16457567601689993), 'MBE': np.float64(0.06712846094802345), 'NSE': np.float64(-165.66895030386115)}
#
# Training model dengan epochs_10_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.4760790817133581, 'RMSE': np.float64(0.13687109999782193), 'MBE': np.float64(0.04972669552765777), 'NSE': np.float64(-188.38124442379385)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.41812265194255704, 'RMSE': np.float64(0.1442429559354082), 'MBE': np.float64(0.008294950152387494), 'NSE': np.float64(-156.18896990634195)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.4377394809874341, 'RMSE': np.float64(0.14179067919787894), 'MBE': np.float64(0.03826791752439928), 'NSE': np.float64(-167.25333166746495)}
#
# Training model dengan epochs_10_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.4760112425128511, 'RMSE': np.float64(0.13687996099680144), 'MBE': np.float64(-0.047983788582939585), 'NSE': np.float64(-185.66478525463367)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': 0.46283218315741903, 'RMSE': np.float64(0.13859063377205605), 'MBE': np.float64(-0.032803829109614345), 'NSE': np.float64(-156.07917756380854)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step
# {'R2': 0.42943024500859706, 'RMSE': np.float64(0.14283454694883607), 'MBE': np.float64(0.04826719095267568), 'NSE': np.float64(-160.24822823984246)}
#
# Training model dengan epochs_10_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.2201596384329516, 'RMSE': np.float64(0.1669866463464402), 'MBE': np.float64(0.07280840372671045), 'NSE': np.float64(-164.71236264441796)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.314034613349931, 'RMSE': np.float64(0.15661378633393994), 'MBE': np.float64(-0.05028031195467876), 'NSE': np.float64(-156.92010320103623)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# {'R2': -1.0936281265250258e-05, 'RMSE': np.float64(0.18909553012971758), 'MBE': np.float64(-0.0006253364211933451), 'NSE': np.float64(-133.00146546168952)}
#
# Training model dengan epochs_10_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.12944122344412157, 'RMSE': np.float64(0.17643223568826918), 'MBE': np.float64(-0.013304835230680415), 'NSE': np.float64(-135.15944221195713)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# {'R2': 0.27226204211218163, 'RMSE': np.float64(0.16131189837414298), 'MBE': np.float64(0.05790381637781515), 'NSE': np.float64(-161.7726867026526)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step
# {'R2': 0.38109472816072054, 'RMSE': np.float64(0.14876164745470136), 'MBE': np.float64(-0.003428410311366959), 'NSE': np.float64(-155.59551147749562)}
#
# Training model dengan epochs_30_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.4901027964583252, 'RMSE': np.float64(0.13502687086037976), 'MBE': np.float64(0.0038959207533554724), 'NSE': np.float64(-171.46156583313606)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# {'R2': 0.16819888986991338, 'RMSE': np.float64(0.17246010099575604), 'MBE': np.float64(0.06161191874285344), 'NSE': np.float64(-155.16091038291432)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.25449144041702676, 'RMSE': np.float64(0.16326955361187626), 'MBE': np.float64(0.054145452396070014), 'NSE': np.float64(-156.78669239276235)}
#
# Training model dengan epochs_30_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.383403188675279, 'RMSE': np.float64(0.14848395454605678), 'MBE': np.float64(0.043384651344090384), 'NSE': np.float64(-168.04119362617814)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.36189982599315196, 'RMSE': np.float64(0.15105090088522902), 'MBE': np.float64(0.049732067396268155), 'NSE': np.float64(-163.51073963462454)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# {'R2': 0.5431160786072984, 'RMSE': np.float64(0.12781500036878762), 'MBE': np.float64(0.00485768373142529), 'NSE': np.float64(-170.09590399314226)}
#
# Training model dengan epochs_30_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# {'R2': 0.5922539090811161, 'RMSE': np.float64(0.12074628879367479), 'MBE': np.float64(0.014076103174740824), 'NSE': np.float64(-175.60375217572118)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.37773309346697237, 'RMSE': np.float64(0.14916510588068013), 'MBE': np.float64(0.04682791070071721), 'NSE': np.float64(-159.83414545001162)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.47294484107789225, 'RMSE': np.float64(0.13727989002754148), 'MBE': np.float64(0.0608091333622907), 'NSE': np.float64(-192.65598874427218)}
#
# Training model dengan epochs_30_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.6561347356531579, 'RMSE': np.float64(0.11088506160573762), 'MBE': np.float64(0.003654965195959306), 'NSE': np.float64(-197.34485333979404)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.6710040344776835, 'RMSE': np.float64(0.10846114238154285), 'MBE': np.float64(0.01705390085289829), 'NSE': np.float64(-183.79602267612253)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
# {'R2': 0.6433063486484774, 'RMSE': np.float64(0.11293448560176364), 'MBE': np.float64(0.022184972925738736), 'NSE': np.float64(-181.29170316891202)}
#
# Training model dengan epochs_30_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# {'R2': -0.01978622617193948, 'RMSE': np.float64(0.19095606611486166), 'MBE': np.float64(0.026598697649775283), 'NSE': np.float64(-135.65135430703987)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step
# {'R2': 0.5669063195263342, 'RMSE': np.float64(0.1244428106983671), 'MBE': np.float64(0.042124273098992894), 'NSE': np.float64(-173.4921227429681)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.46117757014961547, 'RMSE': np.float64(0.1388039167940953), 'MBE': np.float64(0.08676309353634594), 'NSE': np.float64(-209.814109401185)}
#
# Training model dengan epochs_30_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.5137713267887589, 'RMSE': np.float64(0.1318557797066576), 'MBE': np.float64(-0.06052121082538886), 'NSE': np.float64(-177.61905598402768)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# {'R2': 0.3209868426043694, 'RMSE': np.float64(0.15581812826543973), 'MBE': np.float64(0.043498449288073886), 'NSE': np.float64(-159.42392050250024)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
# {'R2': 0.29082433251770956, 'RMSE': np.float64(0.15924133188110817), 'MBE': np.float64(0.05943196170620166), 'NSE': np.float64(-169.65694702072537)}
#
# Training model dengan epochs_50_lr_0.0001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# {'R2': 0.4964283735635847, 'RMSE': np.float64(0.1341867128719556), 'MBE': np.float64(0.01705711283155443), 'NSE': np.float64(-171.19145290477294)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# {'R2': 0.32258677359834587, 'RMSE': np.float64(0.15563444605235574), 'MBE': np.float64(0.03547044424678064), 'NSE': np.float64(-155.16886032056405)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step
# {'R2': 0.2842670578336276, 'RMSE': np.float64(0.15997583714313615), 'MBE': np.float64(0.05009513185349965), 'NSE': np.float64(-162.7504606036502)}
#
# Training model dengan epochs_50_lr_0.0001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.4764906827865977, 'RMSE': np.float64(0.1368173253166434), 'MBE': np.float64(-0.008583826211084946), 'NSE': np.float64(-169.61450153763195)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5081303831273696, 'RMSE': np.float64(0.13261843134671022), 'MBE': np.float64(0.018592795923451116), 'NSE': np.float64(-175.97698914369516)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.5339850349395041, 'RMSE': np.float64(0.12908590383285362), 'MBE': np.float64(0.03279709030252885), 'NSE': np.float64(-181.08301939207092)}
#
# Training model dengan epochs_50_lr_0.001_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.6208119308880968, 'RMSE': np.float64(0.11644107877407407), 'MBE': np.float64(0.026229178765692942), 'NSE': np.float64(-184.75160622268191)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.5735093497350316, 'RMSE': np.float64(0.12349052747584324), 'MBE': np.float64(0.019800569399845366), 'NSE': np.float64(-178.85193619611724)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.6393083609181458, 'RMSE': np.float64(0.11356563300502676), 'MBE': np.float64(0.022907774210742284), 'NSE': np.float64(-195.00601444267485)}
#
# Training model dengan epochs_50_lr_0.001_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# {'R2': 0.6289899381900212, 'RMSE': np.float64(0.11517858325033542), 'MBE': np.float64(-0.003327756748394164), 'NSE': np.float64(-176.0444960788403)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# {'R2': 0.6305905312677503, 'RMSE': np.float64(0.11492986586385667), 'MBE': np.float64(-0.0036261040169257358), 'NSE': np.float64(-171.76664919391126)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.6097479972846293, 'RMSE': np.float64(0.11812762122269614), 'MBE': np.float64(0.02252090047799041), 'NSE': np.float64(-178.43816872735243)}
#
# Training model dengan epochs_50_lr_0.01_opt_adam_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step
# {'R2': 0.6966022678609901, 'RMSE': np.float64(0.10415618237208056), 'MBE': np.float64(-0.014026858986437196), 'NSE': np.float64(-194.46725229269964)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_16
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# {'R2': 0.542980945042117, 'RMSE': np.float64(0.12783390103360875), 'MBE': np.float64(0.028160219688790185), 'NSE': np.float64(-162.91585433450211)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_32
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.7104276341082167, 'RMSE': np.float64(0.10175539523501458), 'MBE': np.float64(0.004301090665594088), 'NSE': np.float64(-199.76212625404284)}
#
# Training model dengan epochs_50_lr_0.01_opt_rmsprop_units_64
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# {'R2': 0.6764853027278456, 'RMSE': np.float64(0.10755383389828709), 'MBE': np.float64(-0.02322432250419557), 'NSE': np.float64(-200.13298314063107)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units        R2      RMSE       MBE  \
# 0       10         0.0001      adam          16  0.085855  0.180795  0.056762
# 1       10         0.0001      adam          32  0.289578  0.159381  0.027093
# 2       10         0.0001      adam          64  0.403148  0.146087  0.006721
# 3       10         0.0001   rmsprop          16  0.184379  0.170775  0.019826
# 4       10         0.0001   rmsprop          32  0.171527  0.172115  0.054388
# 5       10         0.0001   rmsprop          64  0.393217  0.147298 -0.000951
# 6       10         0.0010      adam          16 -0.050346  0.193796  0.110795
# 7       10         0.0010      adam          32  0.242516  0.164576  0.067128
# 8       10         0.0010      adam          64  0.476079  0.136871  0.049727
# 9       10         0.0010   rmsprop          16  0.418123  0.144243  0.008295
# 10      10         0.0010   rmsprop          32  0.437739  0.141791  0.038268
# 11      10         0.0010   rmsprop          64  0.476011  0.136880 -0.047984
# 12      10         0.0100      adam          16  0.462832  0.138591 -0.032804
# 13      10         0.0100      adam          32  0.429430  0.142835  0.048267
# 14      10         0.0100      adam          64  0.220160  0.166987  0.072808
# 15      10         0.0100   rmsprop          16  0.314035  0.156614 -0.050280
# 16      10         0.0100   rmsprop          32 -0.000011  0.189096 -0.000625
# 17      10         0.0100   rmsprop          64  0.129441  0.176432 -0.013305
# 18      30         0.0001      adam          16  0.272262  0.161312  0.057904
# 19      30         0.0001      adam          32  0.381095  0.148762 -0.003428
# 20      30         0.0001      adam          64  0.490103  0.135027  0.003896
# 21      30         0.0001   rmsprop          16  0.168199  0.172460  0.061612
# 22      30         0.0001   rmsprop          32  0.254491  0.163270  0.054145
# 23      30         0.0001   rmsprop          64  0.383403  0.148484  0.043385
# 24      30         0.0010      adam          16  0.361900  0.151051  0.049732
# 25      30         0.0010      adam          32  0.543116  0.127815  0.004858
# 26      30         0.0010      adam          64  0.592254  0.120746  0.014076
# 27      30         0.0010   rmsprop          16  0.377733  0.149165  0.046828
# 28      30         0.0010   rmsprop          32  0.472945  0.137280  0.060809
# 29      30         0.0010   rmsprop          64  0.656135  0.110885  0.003655
# 30      30         0.0100      adam          16  0.671004  0.108461  0.017054
# 31      30         0.0100      adam          32  0.643306  0.112934  0.022185
# 32      30         0.0100      adam          64 -0.019786  0.190956  0.026599
# 33      30         0.0100   rmsprop          16  0.566906  0.124443  0.042124
# 34      30         0.0100   rmsprop          32  0.461178  0.138804  0.086763
# 35      30         0.0100   rmsprop          64  0.513771  0.131856 -0.060521
# 36      50         0.0001      adam          16  0.320987  0.155818  0.043498
# 37      50         0.0001      adam          32  0.290824  0.159241  0.059432
# 38      50         0.0001      adam          64  0.496428  0.134187  0.017057
# 39      50         0.0001   rmsprop          16  0.322587  0.155634  0.035470
# 40      50         0.0001   rmsprop          32  0.284267  0.159976  0.050095
# 41      50         0.0001   rmsprop          64  0.476491  0.136817 -0.008584
# 42      50         0.0010      adam          16  0.508130  0.132618  0.018593
# 43      50         0.0010      adam          32  0.533985  0.129086  0.032797
# 44      50         0.0010      adam          64  0.620812  0.116441  0.026229
# 45      50         0.0010   rmsprop          16  0.573509  0.123491  0.019801
# 46      50         0.0010   rmsprop          32  0.639308  0.113566  0.022908
# 47      50         0.0010   rmsprop          64  0.628990  0.115179 -0.003328
# 48      50         0.0100      adam          16  0.630591  0.114930 -0.003626
# 49      50         0.0100      adam          32  0.609748  0.118128  0.022521
# 50      50         0.0100      adam          64  0.696602  0.104156 -0.014027
# 51      50         0.0100   rmsprop          16  0.542981  0.127834  0.028160
# 52      50         0.0100   rmsprop          32  0.710428  0.101755  0.004301
# 53      50         0.0100   rmsprop          64  0.676485  0.107554 -0.023224
#
#            NSE
# 0  -148.651900
# 1  -149.274427
# 2  -158.439288
# 3  -139.060812
# 4  -150.890247
# 5  -155.857659
# 6  -188.007952
# 7  -165.668950
# 8  -188.381244
# 9  -156.188970
# 10 -167.253332
# 11 -185.664785
# 12 -156.079178
# 13 -160.248228
# 14 -164.712363
# 15 -156.920103
# 16 -133.001465
# 17 -135.159442
# 18 -161.772687
# 19 -155.595511
# 20 -171.461566
# 21 -155.160910
# 22 -156.786692
# 23 -168.041194
# 24 -163.510740
# 25 -170.095904
# 26 -175.603752
# 27 -159.834145
# 28 -192.655989
# 29 -197.344853
# 30 -183.796023
# 31 -181.291703
# 32 -135.651354
# 33 -173.492123
# 34 -209.814109
# 35 -177.619056
# 36 -159.423921
# 37 -169.656947
# 38 -171.191453
# 39 -155.168860
# 40 -162.750461
# 41 -169.614502
# 42 -175.976989
# 43 -181.083019
# 44 -184.751606
# 45 -178.851936
# 46 -195.006014
# 47 -176.044496
# 48 -171.766649
# 49 -178.438169
# 50 -194.467252
# 51 -162.915854
# 52 -199.762126
# 53 -200.132983

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}"
best_model = models[best_model_name]

best_model.save("kebun_jeruk.keras")

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0090
# Test Loss: 0.010354160331189632

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Testing Metrics:
# Test R²: 0.7104
# Test RMSE: 0.1018
# Test MBE: 0.0043
# Test NSE: -199.7621

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.legend()
plt.show()
# Out:
#  13/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("kebun_jeruk results.csv", index=False)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.initializers import glorot_uniform

model = load_model("kebun_jeruk.keras")


# Fungsi untuk me-reset bobot model
def reset_weights(model):
    for layer in model.layers:
        # Reset weights untuk layer yang memiliki weights (Dense, Conv2D, LSTM, dll.)
        if hasattr(layer, 'weights'):
            for weight in layer.weights:
                # Dapatkan initializer yang sesuai
                if 'kernel' in weight.name:
                    initializer = layer.kernel_initializer
                elif 'bias' in weight.name:
                    initializer = layer.bias_initializer
                elif 'recurrent_kernel' in weight.name:
                    initializer = layer.recurrent_initializer
                else:
                    continue  # Lewati jika tidak dikenali
                
                # Reset nilai weights
                new_weights = initializer(weight.shape)
                weight.assign(new_weights)
# Reset bobot model
reset_weights(model)


class R2History(Callback):
    def __init__(self, val_gen):
        self.val_gen = val_gen
        self.r2_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_pred = self.model.predict(self.val_gen)

        val_true_list = []
        for i in range(len(test_gen)):  
            _, y =  val_gen[i]  # Ambil hanya nilai target dari generator
            val_true_list.append(y)
        
        val_true = np.hstack(val_true_list)  # Gabungkan list ke array numpy
                        
        r2 = r2_score(val_true, val_pred)
        self.r2_scores.append(r2)

r2_callback = R2History(val_gen)

# %%
history = model.fit(train_gen, validation_data=val_gen, epochs=100, callbacks=[r2_callback])
# Out:
# Epoch 1/100
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step   - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0411 - val_loss: 0.0178
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0173 - val_loss: 0.0209
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0157 - val_loss: 0.0147
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0119 - val_loss: 0.0139
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0136 - val_loss: 0.0204
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0102 - val_loss: 0.0123
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0122 - val_loss: 0.0182
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0102 - val_loss: 0.0114
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0119 - val_loss: 0.0156
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0107 - val_loss: 0.0143
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0114 - val_loss: 0.0221
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0098 - val_loss: 0.0150
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0100 - val_loss: 0.0123
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0099 - val_loss: 0.0105
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0109 - val_loss: 0.0123
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0076 - val_loss: 0.0129
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0107 - val_loss: 0.0109
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0.0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0099 - val_loss: 0.0128
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0073 - val_loss: 0.0128
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0118 - val_loss: 0.0105
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0087 - val_loss: 0.0140
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0077 - val_loss: 0.0128
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0096 - val_loss: 0.0131
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0083 - val_loss: 0.0149
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0067 - val_loss: 0.0100
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0080 - val_loss: 0.0114
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0092 - val_loss: 0.0159
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0072 - val_loss: 0.0101
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.0077 - val_loss: 0.0183
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0078 - val_loss: 0.0104
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0078 - val_loss: 0.0124
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0081 - val_loss: 0.0101
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0085 - val_loss: 0.0114
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0083 - val_loss: 0.0098
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0079 - val_loss: 0.0225
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0079 - val_loss: 0.0136
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0080 - val_loss: 0.0122
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0072 - val_loss: 0.0123
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0075 - val_loss: 0.0122
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0077 - val_loss: 0.0139
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0080 - val_loss: 0.0131
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0073 - val_loss: 0.0098
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0059 - val_loss: 0.0112
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0090 - val_loss: 0.0136
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0074 - val_loss: 0.0107
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0087 - val_loss: 0.0112
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0084 - val_loss: 0.0134
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0069 - val_loss: 0.0097
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0079 - val_loss: 0.0124
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0069 - val_loss: 0.0111
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0076 - val_loss: 0.0109
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0093 - val_loss: 0.0124
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0098 - val_loss: 0.0135
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0080 - val_loss: 0.0112
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0087 - val_loss: 0.0178
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0092 - val_loss: 0.0108
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0069 - val_loss: 0.0154
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0071 - val_loss: 0.0104
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0076 - val_loss: 0.0106
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0067 - val_loss: 0.0111
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0086 - val_loss: 0.0121
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0073 - val_loss: 0.0128
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0072 - val_loss: 0.0132
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0073 - val_loss: 0.0100
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0078 - val_loss: 0.0111
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0064 - val_loss: 0.0117
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0084 - val_loss: 0.0107
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0067 - val_loss: 0.0101
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0074 - val_loss: 0.0147
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0098 - val_loss: 0.0119
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0078 - val_loss: 0.0118
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0065 - val_loss: 0.0112
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0093 - val_loss: 0.0101
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0071 - val_loss: 0.0111
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0059 - val_loss: 0.0163
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0077 - val_loss: 0.0108
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0070 - val_loss: 0.0116
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0064 - val_loss: 0.0130
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0065 - val_loss: 0.0132
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0061 - val_loss: 0.0138
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step ep - loss:
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - loss: 0.0067 - val_loss: 0.0132
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0075 - val_loss: 0.0114
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0063 - val_loss: 0.0109
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0061 - val_loss: 0.0155
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0072 - val_loss: 0.0126
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0076 - val_loss: 0.0112
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0074 - val_loss: 0.0129
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0071 - val_loss: 0.0145
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0079 - val_loss: 0.0107
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0068 - val_loss: 0.0156
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0075 - val_loss: 0.0125
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0065 - val_loss: 0.0108
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0074 - val_loss: 0.0118
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0062 - val_loss: 0.0147
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0069 - val_loss: 0.0127
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step ep - loss: 0
# 182/182 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.0064 - val_loss: 0.0138

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
r2_scores = r2_callback.r2_scores

# %%
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i] 
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  
test_pred = model.predict(test_gen)
# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mbe = np.mean(test_true - test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²: {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MBE: {test_mbe:.4f}")
print(f"Test NSE: {test_nse:.4f}")
# Out:
# 13/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Testing Metrics:
# Test R²: 0.4600
# Test RMSE: 0.1376
# Test MBE: 0.0059
# Test NSE: -151.4284
